# %% [markdown]
# pyLDAvis는 LDA 모델의 학습 결과를 시각적으로 보여주는 유용한 툴킷입니다. 설치법 및 더 자세한 튜토리얼은 [pyLDAvis의 github][pyldavis]을 들어가셔서 보시기 바랍니다.
#
# 우리는 Day4_7에서 학습한 LDA 모델을 시각화 해보겠습니다.
#
# [pyldavis]: https://github.com/bmabey/pyLDAvis/blob/master/notebooks/pyLDAvis_overview.ipynb

# %%
mm_fname = '../../../data/corpus_10days/models/2016-10-24_article_all_normed_corpus.mtx'
dictionary_fname = '../../../data/corpus_10days/models/2016-10-24_article_all_normed_corpus.dictionary'
ldamodel_fname = '../../../data/corpus_10days/models/2016-10-24_article_all_normed_corpus_lda_3_6.pkl'
pyldavis_fname = '../../../data/corpus_10days/models/2016-10-24_article_all_normed_corpus_pyldavis.pkl'

import pickle
from scipy.io import mmread
import gensim

dictionary = gensim.corpora.Dictionary.load_from_text(dictionary_fname)
corpus = gensim.matutils.Sparse2Corpus(mmread(mm_fname).transpose())
with open(ldamodel_fname, 'rb') as f:
    lda = pickle.load(f)

# %% [markdown]
# lda 모델이 제대로 로딩되었는지 show_topics()를 이용하여 살펴봅니다

# %%
lda.show_topics(num_words=5)
# Out:
# [(9, '0.020*"행사" + 0.018*"지난" + 0.016*"참여" + 0.014*"제공" + 0.013*"000원"'),
#  (8, '0.045*"예산" + 0.034*"정부" + 0.030*"대통령" + 0.028*"국회" + 0.019*"예산안"'),
#  (1, '0.030*"사진" + 0.022*"제품" + 0.021*"선보" + 0.021*"패션" + 0.018*"브랜드"'),
#  (6, '0.045*"제보" + 0.044*"배포" + 0.040*"라이브" + 0.039*"기억" + 0.020*"동영상"'),
#  (33, '0.050*"트와이스" + 0.030*"공개" + 0.024*"앨범" + 0.023*"걸그룹" + 0.020*"사랑"'),
#  (29, '0.061*"사진" + 0.054*"영상" + 0.027*"진영" + 0.025*"잠시" + 0.024*"24"'),
#  (2, '0.029*"웃음" + 0.019*"클린턴" + 0.019*"있습니다" + 0.018*"트럼프" + 0.018*"미국"'),
#  (30, '0.057*"북한" + 0.027*"외교" + 0.025*"중국" + 0.024*"우리" + 0.016*"정부"'),
#  (12, '0.024*"총장" + 0.019*"청춘" + 0.016*"충남" + 0.015*"대학" + 0.012*"한국"'),
#  (49, '0.021*"때문" + 0.021*"생각" + 0.016*"하지" + 0.015*"문제" + 0.011*"지금"')]

# %% [markdown]
# pyLDAvis.gensim.prepare()를 이용하면 시각화 할 준비를 합니다.

# %%
import pyLDAvis

print(pyLDAvis.__version__)
# Out:
# 2.1.1

# %%
import pyLDAvis.gensim as gensimvis
prepared_data = gensimvis.prepare(lda, corpus, dictionary)
# Out:
# /home/lovit/anaconda2/envs/scrapper/lib/python3.6/site-packages/pyLDAvis/_prepare.py:387: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   topic_term_dists = topic_term_dists.ix[topic_order]
# /home/lovit/anaconda2/envs/scrapper/lib/python3.6/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))

# %% [markdown]
# pyLDAvis.display()를 하면 interactive display가 됩니다.
#
# $relevance(w \vert t) = \lambda \times p(w \vert t) + (1 - \lambda) * \frac{p(w \vert t)}{p(w)}$
# - w: term
# - t: topic

# %%
pyLDAvis.display(prepared_data)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el120811399927007138641225076189"></div>
# <script type="text/javascript">
#
# ...

# %% [markdown]
# pyldavis 역시 pickling이 가능합니다.

# %%
# with open(pyldavis_fname, 'wb') as f:
#     pickle.dump(prepared_data, f)

# %% [markdown]
# loaded_pyldavis 역시 동일하게 시각화가 됩니다.

# %%
import pickle
import pyLDAvis

with open(pyldavis_fname, 'rb') as f:
    loaded_prepared_data = pickle.load(f)
pyLDAvis.display(loaded_prepared_data)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el120811399937065064243711727316"></div>
# <script type="text/javascript">
#
# ...

# %% [markdown]
# html 로 저장이 가능합니다.

# %%
pyLDAvis.save_html(prepared_data, 'pyldavis.html')
