# %% [markdown]
# ## 주의
#
# 이 tutorials 는 큰 용량의 메모리를 요구합니다. 충분한 메모리가 확보된 각자의 환경에서만 테스트 해보시길 권장합니다.
#
# Scikit-learn 의 logistic regression 을 이용하기 위하여 데이터를 한 번에 메모리에 올리기 때문인데, 대략 20 GB 를 이용합니다.
#
# 이 부분은 PyTorch 나 TensorFlow 로 훨씬 효율적으로 구현할 수 있습니다. 이후에 효율적인 구현체를 추가로 올리겠습니다.

# %% [markdown]
# ## Load dataset
#
# Comments 는 list of str 형식의 문장을 yield 하는 데이터클래스 입니다. 영화평 데이터는 (영화 id, 영화평, 평점) 의 column data 이기 때문에 영화평만 선택하여 띄어쓰기 기준으로 split 합니다.

# %%
import config
from navermovie_comments import get_movie_comments_path

class Comments:
    def __init__(self, path):
        self.path = path
    def __iter__(self):
        with open(self.path, encoding='utf-8') as f:
            for i, doc in enumerate(f):
                idx, text, rate = doc.split('\t')
                yield text.split()

path = get_movie_comments_path(large=True, tokenize='soynlp_unsup')
comments = Comments(path)

for i, sent in enumerate(comments):
    if i >= 3:
        break
    print(sent)
# Out:
# soynlp=0.0.49
# added lovit_textmining_dataset
# ['명불허전']
# ['왠지', '고사', '피의', '중간', '고사', '보다', '재미', '가', '없을듯', '해요', '만약', '보게', '된다면', '실망', '할듯']
# ['티아라', '사랑', '해', 'ㅜ']

# %% [markdown]
# ## Scan vocabulary
#
# 데이터에 존재하는 단어들을 `min_count` 기준으로 필터링합니다. Return 값으로 vocabulary index 와 count 를 return 합니다.

# %%
from collections import defaultdict

def scan_vocabulary(sents, min_count, verbose=False):
    counter = defaultdict(int)
    for i, sent in enumerate(sents):
        if verbose and i % 100000 == 0:
            print('\rscanning vocabulary .. from %d sents' % i, end='')
        for word in sent:
            counter[word] += 1
    counter = {word:count for word, count in counter.items()
               if count >= min_count}
    idx_to_vocab = [vocab for vocab in sorted(counter,
                    key=lambda x:-counter[x])]
    vocab_to_idx = {vocab:idx for idx, vocab in enumerate(idx_to_vocab)}
    idx_to_count = [counter[vocab] for vocab in idx_to_vocab]
    if verbose:
        print('\rscanning vocabulary was done. %d terms from %d sents' % (len(idx_to_vocab), i+1))
    return vocab_to_idx, idx_to_vocab, idx_to_count

vocab_to_idx, idx_to_vocab, idx_to_count = scan_vocabulary(
    comments, min_count=10, verbose=True)
# Out:
# scanning vocabulary was done. 69541 terms from 3280685 sents

# %% [markdown]
# scan_vocabulary 의 return 값을 살펴봅니다.

# %%
print(idx_to_vocab[:5])
print(idx_to_count[:5])
# Out:
# ['영화', '이', '관람', '객', '의']
# [1128809, 866305, 600351, 526070, 489950]

# %% [markdown]
# ## Features
#
# 우리는 window = 2 를 이용하여 한 단어 X[0] 의 앞, 뒤 각각 두 개의 단어 (총 4개의 단어)를 X[0] 의 features 로 이용합니다. 예를 들어 (a, b, c, d, e) 라는 단어가 등장하였고, X[0]=c 라면 X[-2]=a, X[-1]=b, X[1]=d, X[2]=e 입니다.
#
# 그리고 scan vocabulary 함수를 통하여 학습된 단어가 총 5 개라면 이들의 위치를 보존하면 X[0] 에 대한 feature space 를 20 만 차원으로 만들 수 있습니다. 만약 각 단어의 index 가 {a:0, b:1, c:2, d:3, e:4} 라면 X[0]=c 는 [0, 5+1, 10+3, 15+4] 를 features 로 가진다 표현할 수 있습니다.
#
# feature_to_idx 는 이를 만드는 함수입니다. 문장 내에서 현재 단어 X[0] 의 위치를 i, 현재 단어 앞, 뒤 단어인 X[-1] 이나 X[1] 의 위치를 j, j 위치의 단어의 index 를 vocab_idx 라 할 때, 이 값의 feature index 를 출력합니다.

# %%
def feature_to_idx(i, j, vocab_idx, window, n_terms):
    if j < i:
        return n_terms * (j - i + window) + vocab_idx
    else:
        return n_terms * (j - i + window - 1) + vocab_idx

feature_to_idx(i=2, j=3, vocab_idx=3, window=2, n_terms=5)
# Out:
# 13

# %% [markdown]
# idx_to_feature 는 반대로 feature index 를 feature 로 decode 합니다. feature idx 를 vocabulary 의 개수로 나눈 몫은 상대적 위치값이 되고, 나머지는 vocabulary idx 입니다.

# %%
def idx_to_feature(feature_idx, idx_to_vocab, window):
    # 몫
    position = feature_idx // len(idx_to_vocab)
    if position < window:
        feature = 'X[-%d] = ' % (window - position)
    else:
        feature = 'X[%d] = ' % (position - window + 1)
    # 나머지
    vocab_idx = feature_idx % len(idx_to_vocab)
    feature += idx_to_vocab[vocab_idx]
    return feature

idx_to_feature(13, 'a b c d e'.split(), window=2)
# Out:
# 'X[1] = d'

# %% [markdown]
# 이를 이용하여 학습데이터로부터 window classification 용 데이터를 만듭니다. X[0] 을 기준으로 X[-2], X[-1], X[1], X[2] 의 co-occurrence 를 계산하는 matrix 를 만듭니다. Sparse matrix 형식이기 때문에 rows, columns 를 따로 모읍니다. words 는 각 rows 에 해당하는 단어를 넣어둡니다.
#
# 아래 부분에서 scan vocabulary 의 결과에 포함되지 않은 단어는 건너 띄며, context words 의 범위는 문장의 맨 앞에서 문장의 맨 뒷 단어가 되도록 index 의 범위를 확인합니다.
#
# ```python
# for i, word in enumerate(sent):
#     if not (word in vocab_to_idx):
#         continue
#
#     b = max(0, i - window)
#     e = min(i + window, n_words)
# ```
#
# 아래 구문을 통하여 sent[j] 의 단어 역시 scan vocabulary 의 결과에 포함되지 않으면 이를 이용하지 않습니다.
#
# ```python
# for j in range(b, e):
#     if i == j:
#         continue
#     j_idx = vocab_to_idx.get(sent[j], -1)
#     if j_idx == -1:
#         continue
# ```

# %%
import numpy as np
from scipy.sparse import csr_matrix

def create_window_cooccurrence_matrix(vocab_to_idx, sentences, window=2, verbose=True):

    n_terms = len(vocab_to_idx)

    rows = []
    cols = []
    words = []

    row_idx = 0
    col_idx = window * 2 * n_terms

    for i_sent, sent in enumerate(sentences):

        if verbose and i_sent % 10000 == 0:
            print('\rcreating train dataset {} rows from {} sents'.format(row_idx, i_sent), end='')

        n_words = len(sent)

        for i, word in enumerate(sent):
            if not (word in vocab_to_idx):
                continue

            b = max(0, i - window)
            e = min(i + window, n_words)

            features = []
            for j in range(b, e):
                if i == j:
                    continue
                j_idx = vocab_to_idx.get(sent[j], -1)
                if j_idx == -1:
                    continue
                features.append(feature_to_idx(i, j, j_idx, window, n_terms))

            if not features:
                continue

            # sparse matrix element
            for col in features:
                rows.append(row_idx)
                cols.append(col)

            # words element
            words.append(word)

            row_idx += 1

    if verbose:
        print('\rtrain dataset {} rows from {} sents was created    '.format(row_idx, i_sent))

    # to csr matrix
    rows = np.asarray(rows, dtype=np.int)
    cols = np.asarray(cols, dtype=np.int)
    data = np.ones(rows.shape[0], dtype=np.int)
    X = csr_matrix((data, (rows, cols)), shape=(row_idx, col_idx))

    return X, words

# %%
window = 2

X, words = create_window_cooccurrence_matrix(
    vocab_to_idx, comments, window)
# Out:
# train dataset 42981576 rows from 3280684 sents was created

# %% [markdown]
# ## Word2Vec 을 이용한 seed set 만들기
#
# 미리 학습해둔 Word2Vec model 을 로딩합니다. 우리는 사람 이름을 인식하는 named entity recognizer 를 만들겁니다. `송강호`와 `디카프리오`의 Word2Vec 유사어는 사람 이름임을 알 수 있습니다. 각각 100 개씩의 유사어를 선택하여 이의 합집합을 seed_words 로 선택합니다. 총 172 개의 단어가 seeds 로 선택되었습니다.

# %%
from pprint import pprint
from navermovie_comments import load_trained_embedding


word2vec = load_trained_embedding(tokenize='soynlp_unsup')

pprint(word2vec.wv.most_similar('송강호', topn=10))
pprint(word2vec.wv.most_similar('디카프리오', topn=10))

seed_words = {word for word, _ in word2vec.most_similar('송강호', topn=100)}
seed_words.update({word for word, _ in word2vec.most_similar('디카프리오', topn=100)})

len(seed_words)
# Out:
# [('하정우', 0.9089709520339966),
#  ('한석규', 0.882610023021698),
#  ('오달수', 0.8565834760665894),
#  ('이정재', 0.8554919958114624),
#  ('김명민', 0.8462209105491638),
#  ('이범수', 0.8421300649642944),
#  ('설경구', 0.8421212434768677),
#  ('황정민', 0.8380463719367981),
#  ('손현주', 0.8376869559288025),
#  ('김윤석', 0.8338449597358704)]
# [('레오', 0.8400799036026001),
#  ('톰하디', 0.8309459686279297),
#  ('앤해서웨이', 0.775414764881134),
#  ('앤헤서웨이', 0.7646037340164185),
#  ('브래드피트', 0.7506041526794434),
#  ('로다주', 0.7499849796295166),
#  ('로버트드니로', 0.7493538856506348),
#  ('콜린퍼스', 0.737823486328125),
#  ('히스레저', 0.7330209016799927),
#  ('윌스미스', 0.7309495806694031)]
# /home/lovit/anaconda2/envs/scrapper/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# /home/lovit/anaconda2/envs/scrapper/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   # Remove the CWD from sys.path while we load stuff.
# /home/lovit/anaconda2/envs/scrapper/lib/python3.6/site-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   # This is added back by InteractiveShellApp.init_path()
# 172

# %%
pprint(word2vec.wv.most_similar('송강호', topn=100))
pprint(word2vec.wv.most_similar('디카프리오', topn=100))
# Out:
# [('하정우', 0.9089709520339966),
#  ('한석규', 0.882610023021698),
#  ('오달수', 0.8565834760665894),
#  ('이정재', 0.8554919958114624),
#  ('김명민', 0.8462209105491638),
#  ('이범수', 0.8421300649642944),
#  ('설경구', 0.8421212434768677),
#  ('황정민', 0.8380463719367981),
#  ('손현주', 0.8376869559288025),
#  ('김윤석', 0.8338449597358704),
#  ('유해진', 0.8303444385528564),
#  ('주진모', 0.828080952167511),
#  ('공유', 0.8169301748275757),
#  ('이병헌', 0.8125848770141602),
#  ('문정희', 0.8114207983016968),
#  ('정우', 0.8097195029258728),
#  ('최민식', 0.8086514472961426),
#  ('안성기', 0.8084512948989868),
#  ('김윤진', 0.805782675743103),
#  ('성동일', 0.7982152700424194),
#  ('조진웅', 0.7979434728622437),
#  ('조정석', 0.7975532412528992),
#  ('안성기씨', 0.7943410873413086),
#  ('류승룡', 0.7933757901191711),
#  ('정재영씨', 0.790336012840271),
#  ('진구', 0.7890698909759521),
#  ('손예진', 0.7869455814361572),
#  ('이하늬', 0.7824959754943848),
#  ('이제훈', 0.7823973894119263),
#  ('감우성', 0.7821334600448608),
#  ('정재영', 0.7818644046783447),
#  ('박신양', 0.7780541181564331),
#  ('고수', 0.7775152921676636),
#  ('윌스미스', 0.7771785259246826),
#  ('마동석', 0.7764662504196167),
#  ('곽도원', 0.7764561176300049),
#  ('김혜수', 0.7726145386695862),
#  ('박신혜', 0.7702970504760742),
#  ('한석규씨', 0.7700535655021667),
#  ('김원해', 0.7668038606643677),
#  ('김민희', 0.7653989791870117),
#  ('정우성', 0.7643895149230957),
#  ('김정태', 0.7633472681045532),
#  ('브래드피트', 0.7599846124649048),
#  ('류승범', 0.7585113048553467),
#  ('심은경', 0.7557778358459473),
#  ('이선균', 0.7538830041885376),
#  ('김태리', 0.7530508041381836),
#  ('임지연', 0.7509555816650391),
#  ('박소담', 0.7501715421676636),
#  ('김윤식', 0.7493447065353394),
#  ('박해일', 0.748423159122467),
#  ('라미란씨', 0.7483770251274109),
#  ('전지현', 0.7472589612007141),
#  ('김인권', 0.74676913022995),
#  ('임달화', 0.745358407497406),
#  ('박성웅', 0.7446509599685669),
#  ('김인권씨', 0.7445727586746216),
#  ('장윤주', 0.7429871559143066),
#  ('박중훈', 0.7417292594909668),
#  ('송중기', 0.7383934259414673),
#  ('라미란', 0.7360476851463318),
#  ('배두나', 0.7360320091247559),
#  ('정진영', 0.7339966893196106),
#  ('권상우', 0.7329936027526855),
#  ('차태현', 0.7325795888900757),
#  ('엄태구', 0.7322331070899963),
#  ('유아인', 0.7317869663238525),
#  ('김해숙씨', 0.7310291528701782),
#  ('문소리', 0.730108380317688),
#  ('김남길', 0.7300806045532227),
#  ('차승원', 0.7291455268859863),
#  ('톰크루즈', 0.7283414602279663),
#  ('서교', 0.7267834544181824),
#  ('박희순', 0.7265297174453735),
#  ('박시후', 0.7262597680091858),
#  ('신하균', 0.7257373332977295),
#  ('하지원', 0.725263237953186),
#  ('송지효', 0.7241121530532837),
#  ('이병현', 0.7236171960830688),
#  ('이경영', 0.7211340665817261),
#  ('조재현', 0.7209962606430054),
#  ('이범수씨', 0.7192143797874451),
#  ('강동원', 0.718712568283081),
#  ('박철민씨', 0.7179031372070312),
#  ('박유천', 0.7166516780853271),
#  ('송새벽', 0.7162311673164368),
#  ('김옥빈', 0.7149441838264465),
#  ('차인표', 0.7145849466323853),
#  ('앤해서웨이', 0.7138860821723938),
#  ('조인성', 0.7136949300765991),
#  ('한예리', 0.7111474275588989),
#  ('박희순씨', 0.7093228697776794),
#  ('앤헤서웨이', 0.7088062763214111),
#  ('유혜진', 0.7079468965530396),
#  ('안소희', 0.7064894437789917),
#  ('주지훈', 0.7055825591087341),
#  ('이민기', 0.7029565572738647),
#  ('류승용', 0.7018036246299744),
#  ('신세경', 0.7017651200294495)]
# [('레오', 0.8400799036026001),
#  ('톰하디', 0.8309459686279297),
#  ('앤해서웨이', 0.775414764881134),
#  ('앤헤서웨이', 0.7646037340164185),
#  ('브래드피트', 0.7506041526794434),
#  ('로다주', 0.7499849796295166),
#  ('로버트드니로', 0.7493538856506348),
#  ('콜린퍼스', 0.737823486328125),
#  ('히스레저', 0.7330209016799927),
#  ('윌스미스', 0.7309495806694031),
#  ('니콜라스홀트', 0.7301133871078491),
#  ('안성기', 0.7279090881347656),
#  ('히스레져', 0.7230311632156372),
#  ('레오나르도', 0.7169990539550781),
#  ('에디', 0.7131405472755432),
#  ('피트', 0.7106266021728516),
#  ('베네딕트', 0.7104400396347046),
#  ('시저', 0.7083353996276855),
#  ('톰크루즈', 0.705954372882843),
#  ('멧데이먼', 0.7048865556716919),
#  ('레저', 0.7021402716636658),
#  ('마크러팔로', 0.6987575888633728),
#  ('숙희', 0.6975143551826477),
#  ('아놀드', 0.6967937350273132),
#  ('베니', 0.696478009223938),
#  ('안성기씨', 0.694658637046814),
#  ('컴버배치', 0.69287109375),
#  ('조커', 0.6924823522567749),
#  ('정진영씨', 0.6913850903511047),
#  ('러셀크로우', 0.6912276744842529),
#  ('김혜수', 0.6902202367782593),
#  ('고수', 0.6899362802505493),
#  ('레이놀즈', 0.6899000406265259),
#  ('샤오위', 0.6896424889564514),
#  ('휴잭맨', 0.6878435611724854),
#  ('윈슬렛', 0.6872936487197876),
#  ('이정재', 0.6837149262428284),
#  ('콜린', 0.6822975873947144),
#  ('감우성', 0.6817169785499573),
#  ('정진영', 0.6808486580848694),
#  ('권상우', 0.6805791258811951),
#  ('한석규', 0.6798723936080933),
#  ('틸다', 0.678984522819519),
#  ('천우희', 0.6765894889831543),
#  ('이범수', 0.675976574420929),
#  ('공유', 0.6751198768615723),
#  ('히스', 0.6738783121109009),
#  ('자베르', 0.6734288334846497),
#  ('유코', 0.6718294620513916),
#  ('진구', 0.6714943647384644),
#  ('엄태구', 0.6712334752082825),
#  ('아저씨', 0.6709884405136108),
#  ('배두나', 0.6703963279724121),
#  ('태리', 0.6684885025024414),
#  ('하쿠', 0.6674778461456299),
#  ('브래드', 0.6670376062393188),
#  ('중기', 0.6664875149726868),
#  ('히데코', 0.6662113666534424),
#  ('로버트다우니주니어', 0.6656385064125061),
#  ('송중기', 0.6650177240371704),
#  ('정우', 0.6647157073020935),
#  ('동원오빠', 0.6642537117004395),
#  ('이준기', 0.6642463207244873),
#  ('하녀', 0.6642237901687622),
#  ('슈왈제네거', 0.6633196473121643),
#  ('주진모', 0.6626404523849487),
#  ('김범수', 0.6623412370681763),
#  ('홀트', 0.6614110469818115),
#  ('김태리', 0.6612002849578857),
#  ('김해숙씨', 0.6609183549880981),
#  ('샤를리즈', 0.6606467962265015),
#  ('다니엘', 0.6591611504554749),
#  ('토니스타크', 0.6582863926887512),
#  ('퓨리오사', 0.6582484245300293),
#  ('에드워드', 0.6573354005813599),
#  ('김민희', 0.6568877696990967),
#  ('해서웨이', 0.6558891534805298),
#  ('테론', 0.6557713747024536),
#  ('해리', 0.6554449796676636),
#  ('스파이디', 0.6541019678115845),
#  ('케이트', 0.6532948613166809),
#  ('드니로', 0.6525280475616455),
#  ('이중구', 0.6524831056594849),
#  ('김인권씨', 0.6523686647415161),
#  ('마고로비', 0.6522125005722046),
#  ('톰아저씨', 0.6521071195602417),
#  ('강혜정', 0.6518676280975342),
#  ('임달화', 0.6517068147659302),
#  ('벤', 0.6513580083847046),
#  ('하시모토', 0.6511232256889343),
#  ('기럭지', 0.6502435207366943),
#  ('신하균', 0.6497122645378113),
#  ('스미스', 0.6487066745758057),
#  ('맥스', 0.6484938263893127),
#  ('레토', 0.6484717130661011),
#  ('주걸륜', 0.6478371620178223),
#  ('아가씨', 0.6472949981689453),
#  ('미모', 0.6470435857772827),
#  ('효진이', 0.6470425128936768),
#  ('죠니뎁', 0.6465335488319397)]
# /home/lovit/anaconda2/envs/scrapper/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %% [markdown]
# ## Word2Vec 유사어를 이용하여 label vector 만들기
#
# 앞서 만든 X 의 row 에 해당하는 단어가 seed_words 에 포함될 경우, 이 rows 의 값을 1 로, 그렇지 않은 경우 0 으로 지정합니다.
#
# 172 개의 단어가 361,394 번 등장하였습니다.

# %%
y = np.zeros(X.shape[0], dtype=np.int)
for i, word in enumerate(words):
    if word in seed_words:
        y[i] = 1

y.sum()
# Out:
# 361394

# %% [markdown]
# ## Logistic Regression 을 이용한 window classifier 만들기
#
# Logistic regression 을 학습합니다. seed words 를 positive class 로 예측하는 모델을 만듭니다. 그런데 실제로는 사람 이름이면서도 label 을 0 으로 가지는 데이터도 존재합니다. Logistic regression 은 이들에 대해서는 큰 확률값을 지닐 가능성이 높습니다. Training error 를 named entity 의 힌트로 이용하는 것입니다. 이 때의 training error 는 우리가 seed words 를 이용하여 엉성하게 데이터를 준비했기 때문에 발생하는 error 이기 때문입니다.

# %%
from sklearn.linear_model import LogisticRegression

logistic = LogisticRegression()
logistic.fit(X, y)
y_pred = logistic.predict(X)
y_prob = logistic.predict_proba(X)[:,1]
# Out:
# /home/lovit/anaconda2/envs/scrapper/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %% [markdown]
# 모델은 softmax probability 가 0 에 가까운 값이면 일단은 negative class 로 분류하여 loss 가 작을 것입니다. 그리고 사람이 등장하는 문맥에서 등장하는 negative class 의 softmax probability 를 지나치게 줄이려 하면 positive class 의 확률값이 매우 작게 되기 때문에 negative class 이면서 사람인 단어들에 대해서는 0 보다는 크되, 매우 작은 확률을 부여합니다. 이 점을 이용하여 prediction probability 가 0.05 보다 큰 snapshot (row) 들을 `pred_pos` 에 카운팅 합니다.
#
# 이후 해당 단어가 등장한 횟수로 0.05 보다 큰 prediction probability 를 받은 횟수를 나눠 named entity score 를 계산합니다.
#
# 예를 들어 배우 `백윤식` 은 seed words 에 포함되지 않았지만 총 100 번 등장하였고, 그 중 95 번을 0.05 보다 큰 prediction probability 를 받았다면, 이 단어의 named entity score 는 0.95 가 됩니다.

# %%
from collections import Counter

# word count
word_counter = Counter(words)

# prediction count
pred_pos = defaultdict(int)
for row in np.where(y_prob >= 0.05)[0]:
    pred_pos[words[row]] += 1
pred_pos = {word:pos/word_counter[word] for word, pos in pred_pos.items()}

# %% [markdown]
# ## 결과 확인하기
#
# Named entity score 가 큰 순서대로 상위 1000 개의 단어를 선택합니다. 그 중 seed words 에 포함된 단어는 출력하지 않습니다. (단어, 빈도수), score 를 확인합니다. 실제로 `백윤식` 은 293 번 등장했으며, 약 222 번 0.05 보다 큰 probability 를 얻었습니다.

# %%
for word, prob in sorted(pred_pos.items(), key=lambda x:-x[1])[:1000]:
    if word in seed_words:
        continue
    idx = vocab_to_idx[word]
    count = idx_to_count[idx]
    print('{} ({})\t{:.3f}'.format(word, count, prob))
# Out:
# 해서워이 (10)	1.000
# 그브가 (12)	1.000
# 장현성 (11)	1.000
# 왕이고싶었고 (26)	0.962
# 공지영작가 (13)	0.923
# 신정근 (11)	0.909
# 달화 (10)	0.900
# 헤더웨이 (10)	0.900
# 전국환 (10)	0.900
# 헤서웨이 (261)	0.893
# 틸타 (10)	0.889
# 박원상 (23)	0.870
# 패틴슨 (286)	0.864
# 천의 (42)	0.857
# 와저 (188)	0.849
# 동해물 (46)	0.848
# 곽동원 (12)	0.833
# 류승수 (12)	0.833
# 레져 (78)	0.808
# 고슬링 (195)	0.805
# 참바다 (81)	0.802
# 김동욱씨 (10)	0.800
# 동명수 (15)	0.800
# 해써웨 (10)	0.800
# 진짫 (10)	0.800
# 헤스 (10)	0.800
# 김소담 (10)	0.800
# 마형 (15)	0.800
# 계두식 (10)	0.800
# 윤지혜 (26)	0.800
# 유이인 (15)	0.800
# 종석 (183)	0.796
# 하저우 (14)	0.786
# 임현식 (13)	0.769
# 전혜진씨 (13)	0.769
# 크루주 (17)	0.765
# 희순 (21)	0.762
# 백윤식 (293)	0.758
# 손현주아저씨 (37)	0.757
# ㅋㅋ이민기 (80)	0.750
# 설경규 (12)	0.750
# 하장우 (12)	0.750
# 류성룡 (12)	0.750
# 혜정 (12)	0.750
# 톰크르즈 (16)	0.750
# 슈왈제너거 (16)	0.750
# 계룬미 (12)	0.750
# 엄태구씨 (39)	0.744
# 예진이 (36)	0.743
# 김남일 (31)	0.742
# 석규 (28)	0.741
# 패티슨 (27)	0.741
# 이성민 (452)	0.739
# 두연기자 (19)	0.737
# 이병현씨 (19)	0.737
# 쿠르즈 (19)	0.737
# 김윤식씨 (34)	0.735
# 현주 (15)	0.733
# 천호진 (30)	0.733
# 유승룡씨 (15)	0.733
# 히들스턴 (15)	0.733
# 스코티 (26)	0.731
# 시후 (37)	0.730
# 하지원언니 (44)	0.727
# 박종훈 (11)	0.727
# 영애 (11)	0.727
# 철봉이 (11)	0.727
# 성령 (22)	0.727
# 민대령 (12)	0.727
# 송광호씨 (33)	0.727
# 김정태아저씨 (11)	0.727
# 보성 (411)	0.726
# 감우성씨 (98)	0.724
# 김미숙 (64)	0.453
# 오근태 (73)	0.452
# 민기 (106)	0.452
# 홍매 (229)	0.452
# 준코 (31)	0.452
# 안젤라베이비 (51)	0.451
# 톰오빠 (51)	0.451
# 우성님 (20)	0.450
# 아놀드형 (60)	0.450
# 님과 (458)	0.450
# 잭니콜슨 (49)	0.449
# 오지호 (158)	0.449
# 님의 (1774)	0.449
# 꼬마아이 (165)	0.448
# 미키유천 (29)	0.448
# 탑군 (29)	0.448
# 김신부 (30)	0.448
# 슬기 (29)	0.448
# 성냥팔이소녀 (67)	0.448
# 코브 (67)	0.448
# 볼드모트 (220)	0.447
# 달수 (131)	0.446
# 동원이형 (66)	0.446
# 미스봉 (65)	0.446
# 의발 (18)	0.444
# 해진씨 (18)	0.444
# 보영님 (28)	0.444
# 하우어 (18)	0.444
# 김환희 (54)	0.444
# 다니엘헤니 (27)	0.444
# 병헌씨 (36)	0.444
# 우성씨 (18)	0.444
# JB (18)	0.444
# 최진혁씨 (27)	0.444
# 윤진언니 (18)	0.444
# 리빙빙 (27)	0.444
# 우에노주리 (36)	0.444

# %% [markdown]
# ## Named Entity Filter (Feature) 확인하기
#
# 우리는 window instance 를 하나의 row 로 만들었기 때문에 prediction probability 가 높은 instance 를 확인하면, 어떤 context 에서 X[0] 가 사람 이름인지를 확인할 수 있습니다.

# %%
top_instances = np.where(0.7 <= y_prob)[0]
top_probs = y_prob[top_instances]

print(top_instances.shape)
print(top_probs.shape)
# Out:
# (32775,)
# (32775,)

# %% [markdown]
# 32,775 개의 rows 중에는 중복된 것들도 많습니다. 중복된 경우를 정리하여 각 instance 와 count, 그리고 prediction probability 를 정리하는 함수를 만듭니다.

# %%
from collections import defaultdict

def get_unique_top_instances(sample_idxs, probs):

    # slice samples
    X_samples = X[sample_idxs]
    rows, cols = X_samples.nonzero()

    # find unique instance
    instance_prob = {}
    instance_count = defaultdict(int)
    before_row = None

    def update_dict(features, prob):
        features = sorted(features, key=lambda x:x[0])
        instance = ', '.join(f[1] for f in features)
        instance_prob[instance] = prob
        instance_count[instance] += 1
        return []

    features = [] # temporal variable
    for row, feature_idx in zip(rows, cols):
        # update unique dictionary
        if row != before_row and features:
            features = update_dict(features, probs[row])
        # update temporal variable
        before_row = row
        feature = idx_to_feature(feature_idx, idx_to_vocab, window)
        features.append((feature_idx, feature))

    # last elements
    if features:
        update_dict(features, probs[row])

    return instance_prob, instance_count

# %% [markdown]
# 여진히 unique instance (unique input vectors) 의 개수가 많습니다.

# %%
instance_prob, instance_count = get_unique_top_instances(top_instances, top_probs)
len(instance_prob)
# Out:
# 16611

# %% [markdown]
# 빈도수 기준으로 상위 500 개의 instance 를 출력합니다 (probability, count), instance 입니다.
#
# 뒤에 X[1] = '씨' 가 등장하는 경우가 가장 많았으며, 아래쪽에는 다음과 같은 표현도 있습니다. `믿고보는 송강호` 와 같은 전형적인 영화평 도메인에서의 표현입니다.
#
# ```
# (0.8705, 16)	X[-2] = 역시, X[-1] = 믿고보는, X[1] = 과
# ```
#
# 아래의 표현은 `아놀드`가 seed words 에 포함되었기 때문에 `슈왈제네거`라는 단어 앞의 단어를 사람 이름으로 인식한 경우입니다.
#
# ```
# (0.9849, 71)	X[1] = 슈왈제네거
# ```
#
# 또한 영화평에서는 배우의 이름을 나열하는 경우들도 있습니다. 배우의 이름을 다 나열한 뒤, '이 캐스팅봐라' 식의 표현들이 있어서 배우 이름 역시 유의미한 context 로 선택됩니다.
#
# ```
# (0.7966, 8)	X[-2] = 강동원, X[-1] = 황정민, X[1] = 이성민
# ```

# %%
sorted_instance_count = sorted(instance_count.items(), key=lambda x:-x[1])

for instance, count in sorted_instance_count[:500]:
    prob = instance_prob[instance]
    print('({:.4}, {})\t{}'.format(prob, count, instance))
# Out:
# (0.7244, 3394)	X[1] = 씨
# (0.9009, 701)	X[1] = 씨의
# (0.8886, 658)	X[-2] = 관람, X[-1] = 객, X[1] = 씨
# (0.7233, 397)	X[1] = 씨가
# (0.9071, 291)	X[-2] = 관람, X[-1] = 객, X[1] = 님
# (0.7244, 182)	X[1] = 씨는
# (0.7797, 172)	X[-2] = 관람, X[-1] = 객, X[1] = 씨의
# (0.8618, 136)	X[1] = 레저
# (0.909, 121)	X[1] = 씨와
# (0.8513, 100)	X[-2] = 재밌, X[-1] = 어요, X[1] = 씨
# (0.7012, 87)	X[-2] = 재밌, X[-1] = 었어요, X[1] = 씨
# (0.7819, 76)	X[-2] = 관람, X[-1] = 객, X[1] = 님의
# (0.7439, 75)	X[-2] = 게, X[-1] = 봤어요, X[1] = 씨
# (0.7826, 73)	X[-2] = 잘, X[-1] = 봤습니다, X[1] = 씨
# (0.9591, 73)	X[-2] = 관람, X[-1] = 객, X[1] = 씨가
# (0.8305, 72)	X[-2] = 개인적, X[-1] = 으로, X[1] = 씨
# (0.8472, 71)	X[1] = 퍼스
# (0.9849, 71)	X[1] = 슈왈제네거
# (0.7257, 69)	X[-2] = 타마코, X[-1] = 나의
# (0.9148, 60)	X[-1] = 히스, X[1] = 의
# (0.7965, 59)	X[1] = 씨랑
# (0.9407, 58)	X[-1] = 믿고보는, X[1] = 배우
# (0.7257, 57)	X[1] = 씨를
# (0.7965, 56)	X[-2] = 게, X[-1] = 봤습니다, X[1] = 씨
# (0.8211, 53)	X[-2] = 있, X[-1] = 었어요, X[1] = 씨
# (0.7439, 50)	X[1] = 피트
# (0.8999, 47)	X[-1] = 역시, X[1] = 님
# (0.8373, 47)	X[-2] = 영화, X[-1] = 였습니다, X[1] = 씨
# (0.7439, 47)	X[-1] = 믿고보는, X[1] = 하정우
# (0.7819, 46)	X[-2] = 영화, X[-1] = 입니다, X[1] = 씨
# (0.9073, 46)	X[-2] = 객, X[-1] = 믿고보는, X[1] = 황정민
# (0.9318, 46)	X[1] = 레드메인
# (0.7679, 45)	X[-2] = 역시, X[-1] = 믿고보는, X[1] = 황정민
# (0.8713, 43)	X[-1] = 역시, X[1] = 형님
# (0.7257, 41)	X[-2] = 영화, X[-1] = 네요, X[1] = 씨
# (0.7289, 39)	X[-1] = 역시, X[1] = 씨
# (0.7168, 39)	X[-2] = 역시, X[-1] = 믿고보는, X[1] = 배우
# (0.8096, 38)	X[-2] = 솔직, X[-1] = 히, X[1] = 씨
# (0.8628, 38)	X[-1] = 아, X[1] = 씨
# (0.9501, 37)	X[-1] = 믿고보는, X[1] = 의
# (0.7244, 37)	X[-2] = 객, X[-1] = 믿고보는, X[1] = 배우
# (0.7261, 37)	X[-2] = 역시, X[-1] = 믿고보는, X[1] = 하정우
# (0.815, 37)	X[-1] = 믿고보는, X[1] = 황정민
# (0.8773, 36)	X[-1] = 니콜라스, X[1] = 의
# (0.8779, 35)	X[-2] = 연기, X[-1] = 와, X[1] = 씨의
# (0.7224, 35)	X[-2] = 객, X[-1] = 믿고보는, X[1] = 의
# (0.7582, 34)	X[-1] = 윌, X[1] = 의
# (0.8715, 33)	X[-2] = 객, X[-1] = 역시, X[1] = 씨
# (0.9082, 33)	X[-1] = 로베르토, X[1] = 니
# (0.8833, 32)	X[-2] = 그래, X[-1] = 도, X[1] = 씨
# (0.7031, 32)	X[-2] = 객, X[-1] = 역시, X[1] = 님
# (0.7439, 32)	X[-2] = 있, X[-1] = 었습니다, X[1] = 씨
# (0.7489, 32)	X[-2] = 와, X[-1] = 앤, X[1] = 의
# (0.7228, 31)	X[-2] = 했, X[-1] = 습니다, X[1] = 씨
# (0.7323, 31)	X[-2] = 관람, X[-1] = 객, X[1] = 씨는
# (0.9008, 30)	X[-2] = 영화, X[-1] = 였어요, X[1] = 씨
# (0.8089, 30)	X[-2] = 좋았, X[-1] = 습니다, X[1] = 씨
# (0.7632, 30)	X[-2] = 재밌, X[-1] = 어요, X[1] = 님
# (0.9351, 29)	X[-2] = 관람, X[-1] = 객, X[1] = 씨와
# (0.7765, 29)	X[-2] = 마지막, X[-1] = 에, X[1] = 씨
# (0.7257, 29)	X[-1] = 믿고보는, X[1] = 역시
# (0.7009, 29)	X[-2] = 관람, X[-1] = 객, X[1] = 퍼스
# (0.9474, 29)	X[-2] = 관람, X[-1] = 객, X[1] = 컴버배치
# (0.8939, 28)	X[-2] = ㅋㅋㅋ, X[-1] = ㅋ, X[1] = 씨
# (0.8445, 28)	X[-2] = 재밌, X[-1] = 었습니다, X[1] = 씨
# (0.7031, 27)	X[-2] = 잘, X[-1] = 봤어요, X[1] = 씨
# (0.9521, 27)	X[-1] = 니콜라스, X[1] = 가
# (0.7186, 26)	X[-1] = 앤, X[1] = 의
# (0.7045, 26)	X[-2] = 황정민, X[-1] = 오달수, X[1] = 연기
# (0.7362, 25)	X[-1] = 진짜, X[1] = 씨
# (0.7747, 25)	X[-2] = 재미, X[-1] = 있네요, X[1] = 씨
# (0.8499, 25)	X[-2] = 영화, X[-1] = 였습니다, X[1] = 씨의
# (0.8965, 25)	X[1] = 레져
# (0.878, 25)	X[1] = 스윈튼
# (0.7085, 25)	X[-2] = 는, X[-1] = 왕이고싶었고, X[1] = 은
# (0.7439, 24)	X[-1] = 앤, X[1] = 가
# (0.8383, 24)	X[-2] = 재미, X[-1] = 있어요, X[1] = 씨
# (0.7207, 24)	X[-2] = 재밌, X[-1] = 었어요, X[1] = 님
# (0.895, 24)	X[-2] = 관람, X[-1] = 객, X[1] = 레드메인
# (0.7006, 23)	X[-2] = 있게, X[-1] = 봤어요, X[1] = 씨
# (0.7439, 23)	X[-2] = 영화, X[-1] = 에요, X[1] = 씨
# (0.8749, 23)	X[-2] = 객, X[-1] = 역시, X[1] = 형님
# (0.9257, 23)	X[-2] = 객, X[-1] = 믿고보는, X[1] = 하정우
# (0.8477, 22)	X[-2] = 기대, X[-1] = 됩니다, X[1] = 씨
# (0.8712, 22)	X[1] = 씨만
# (0.781, 22)	X[-2] = ㅠㅠ, X[-1] = ㅠ, X[1] = 씨
# (0.7065, 22)	X[-2] = 같, X[-1] = 습니다, X[1] = 씨
# (0.9157, 21)	X[-1] = 믿고보는, X[1] = 과
# (0.8018, 21)	X[1] = 래드클리프
# (0.8543, 21)	X[-2] = 믿고, X[-1] = 보는, X[1] = 님
# (0.8882, 21)	X[-2] = 역시, X[-1] = 믿고보는, X[1] = 강동원
# (0.7439, 20)	X[-2] = 있, X[-1] = 습니다, X[1] = 씨
# (0.7439, 20)	X[-2] = 무엇, X[-1] = 보다, X[1] = 씨
# (0.708, 20)	X[-2] = 에, X[-1] = 의한, X[1] = 를위
# (0.7272, 20)	X[-2] = 재밌, X[-1] = 습니다, X[1] = 씨
# (0.8626, 20)	X[-2] = 되는, X[-1] = 영화, X[1] = 씨
# (0.7049, 20)	X[-2] = 역시, X[-1] = 믿고보는, X[1] = 님
# (0.7259, 20)	X[1] = 애플렉
# (0.7465, 20)	X[-2] = 믿고보는, X[-1] = 하정우, X[1] = 연기
# (0.9244, 20)	X[-2] = 객, X[-1] = 역시, X[1] = 오달수
# (0.8794, 20)	X[-2] = 객, X[-1] = 믿고보는, X[1] = 오달수
# (0.8046, 20)	X[-2] = 황정민, X[-1] = 과, X[1] = 연기
# (0.8603, 20)	X[-2] = 객, X[-1] = 믿고보는, X[1] = 유아인
# (0.9829, 20)	X[1] = 테론
# (0.7819, 19)	X[-2] = 와중, X[-1] = 에, X[1] = 연기
# (0.7871, 19)	X[-2] = 보고, X[-1] = 왔어요, X[1] = 씨
# (0.742, 19)	X[-2] = 전지현, X[-1] = 하정우, X[1] = 오달수
# (0.7119, 19)	X[-2] = 강동원, X[-1] = 이랑, X[1] = 연기
# (0.8856, 19)	X[-2] = 역시, X[-1] = 믿고보는, X[1] = 유아인
# (0.7209, 18)	X[-2] = 있는, X[-1] = 영화, X[1] = 씨
# (0.8168, 18)	X[-2] = 마지막, X[-1] = 에, X[1] = 씨가
# (0.7012, 18)	X[-2] = 무엇, X[-1] = 보다, X[1] = 씨의
# (0.7021, 18)	X[-2] = 도, X[-1] = 있고, X[1] = 씨
# (0.7627, 18)	X[-2] = 있게, X[-1] = 봤습니다, X[1] = 씨
# (0.7509, 18)	X[-2] = 황정민, X[-1] = 씨와, X[1] = 씨의
# (0.7135, 18)	X[-2] = 전지현, X[-1] = 이정재, X[1] = 오달수
# (0.8263, 18)	X[-2] = 전지현, X[-1] = 하정우, X[1] = 조진웅
# (0.8267, 18)	X[-2] = 송강호, X[-1] = 랑, X[1] = 연기
# (0.8037, 18)	X[-2] = 송강호, X[-1] = 씨와, X[1] = 씨의
# (0.7336, 18)	X[-2] = 믿고보는, X[-1] = 황정민, X[1] = 오달수
# (0.7634, 17)	X[-1] = 믿고보는, X[1] = 표
# (0.8818, 17)	X[-2] = 것, X[-1] = 같아요, X[1] = 씨
# (0.8049, 17)	X[-2] = 믿고보는, X[-1] = 배우, X[1] = 씨
# (0.7276, 17)	X[-2] = 객, X[-1] = 믿고보는, X[1] = 유해진
# (0.8203, 17)	X[-2] = 게, X[-1] = 봤네요, X[1] = 씨
# (0.9512, 17)	X[-2] = 하정우, X[-1] = 이정재, X[1] = 오달수
# (0.9122, 17)	X[-2] = 관람, X[-1] = 객, X[1] = 슈왈제네거
# (0.867, 16)	X[-2] = 좋아, X[-1] = 요, X[1] = 씨
# (0.7142, 16)	X[-2] = 보고, X[-1] = 왔습니다, X[1] = 씨
# (0.7826, 16)	X[-2] = 객, X[-1] = 믿고보는, X[1] = 과
# (0.8338, 16)	X[-1] = 역시, X[1] = 아저씨
# (0.7025, 16)	X[-2] = 하정우, X[-1] = 랑, X[1] = 연기
# (0.7702, 16)	X[-2] = 적이, X[-1] = 고, X[1] = 씨
# (0.8705, 16)	X[-2] = 역시, X[-1] = 믿고보는, X[1] = 과
# (0.8902, 16)	X[-1] = 믿고보는, X[1] = 강동원
# (0.8134, 16)	X[-2] = 객, X[-1] = 믿고보는, X[1] = 강동원
# (0.9692, 16)	X[-1] = 로베르토, X[1] = 니의
# (0.9692, 16)	X[-1] = 니콜라스, X[1] = 때문
# (0.7439, 15)	X[-2] = 꼭, X[-1] = 보세요, X[1] = 씨
# (0.9879, 15)	X[-2] = 믿고, X[-1] = 보는, X[1] = 형님
# (0.8104, 15)	X[-1] = 와, X[1] = 씨
# (0.7747, 15)	X[1] = 씨연
# (0.7443, 15)	X[-2] = 최고, X[-1] = 입니다, X[1] = 씨
# (0.7889, 15)	X[-2] = 믿고보는, X[-1] = 배우, X[1] = 오달수
# (0.8436, 15)	X[-1] = 배우, X[1] = 씨의
# (0.7886, 15)	X[-2] = 와중, X[-1] = 에, X[1] = 존잘
# (0.8837, 15)	X[-2] = 믿고, X[-1] = 보는, X[1] = 오달수
# (0.8831, 15)	X[-2] = 믿고보는, X[-1] = 황정민, X[1] = 의
# (0.9861, 14)	X[-2] = 개인적, X[-1] = 으로, X[1] = 씨의
# (0.814, 14)	X[-2] = 보았습니, X[-1] = 다, X[1] = 씨
# (0.813, 14)	X[-2] = 영화, X[-1] = 입니다, X[1] = 씨의
# (0.7367, 14)	X[-2] = 객, X[-1] = 믿고보는, X[1] = 형님
# (0.7772, 14)	X[-2] = 역시, X[-1] = 믿고보는, X[1] = 의
# (0.8188, 14)	X[-1] = 믿고보는, X[1] = 오달수
# (0.7031, 14)	X[-2] = 객, X[-1] = 믿고보는, X[1] = 와
# (0.9058, 14)	X[-1] = 역시, X[1] = 오달수
# (0.9513, 14)	X[-2] = 역시, X[-1] = 믿고보는, X[1] = 오달수
# (0.7012, 14)	X[-2] = 황정민, X[-1] = 이랑, X[1] = 연기
# (0.8971, 14)	X[-2] = 역시, X[-1] = 황정민, X[1] = 오달수
# (0.7439, 14)	X[-2] = 강동원, X[-1] = 하드캐리, X[1] = 하드캐리
# (0.8177, 14)	X[-1] = 역시, X[1] = 박중훈
# (0.7439, 13)	X[-2] = 김윤석, X[-1] = 씨와, X[1] = 씨
# (0.7668, 13)	X[-2] = 믿고, X[-1] = 보는, X[1] = 아저씨
# (0.7439, 13)	X[-2] = 왔, X[-1] = 는데, X[1] = 씨
# (0.7084, 13)	X[-1] = 믿고보는, X[1] = 와
# (0.7439, 13)	X[-2] = 잘, X[-1] = 봤습니다, X[1] = 씨의
# (0.928, 13)	X[-1] = 믿고보는, X[1] = 유해진
# (0.7266, 13)	X[-2] = 믿고보는, X[-1] = 배우, X[1] = 님
# (0.8885, 13)	X[-2] = 관람, X[-1] = 객, X[1] = 씨를
# (0.9108, 13)	X[-2] = 관람, X[-1] = 객, X[1] = 님과
# (0.7439, 13)	X[-1] = 역시, X[1] = 오빠
# (0.7799, 13)	X[-2] = 객, X[-1] = 믿고보는, X[1] = 연기
# (0.7257, 13)	X[-2] = 재미, X[-1] = 있고, X[1] = 씨
# (0.7996, 13)	X[-2] = 습니다, X[-1] = 특히, X[1] = 씨
# (0.7938, 13)	X[-2] = 황정민, X[-1] = 역시, X[1] = 배우
# (0.7057, 13)	X[-1] = 윌, X[1] = 가
# (0.7466, 13)	X[-2] = 황정민, X[-1] = 곽도원, X[1] = 연기
# (0.8379, 13)	X[-2] = 강동원, X[-1] = 이랑, X[1] = 때문
# (0.7941, 13)	X[-2] = 들, X[-1] = 었습니다, X[1] = 씨의
# (0.7439, 13)	X[1] = 컬렌
# (0.7996, 12)	X[-2] = 김윤석, X[-1] = 씨와, X[1] = 씨의
# (0.8626, 12)	X[-1] = 배우, X[1] = 씨
# (0.7211, 12)	X[-1] = 믿고보는, X[1] = 님
# (0.9351, 12)	X[-1] = 역시, X[1] = 님은
# (0.7559, 12)	X[-2] = 요, X[-1] = 특히, X[1] = 씨
# (0.7679, 12)	X[-2] = 했, X[-1] = 습니다, X[1] = 씨의
# (0.8461, 12)	X[-2] = 한석규, X[-1] = 님, X[1] = 님
# (0.8074, 12)	X[-2] = 영화, X[-1] = 다, X[1] = 씨
# (0.928, 12)	X[-2] = 역시, X[-1] = 믿고보는, X[1] = 유해진
# (0.7098, 12)	X[-2] = 특, X[-1] = 히나, X[1] = 씨
# (0.7509, 12)	X[1] = 에플렉
# (0.8417, 12)	X[-2] = 갠적, X[-1] = 으로, X[1] = 씨
# (0.8713, 12)	X[-2] = 연기, X[-1] = 와, X[1] = 씨
# (0.7257, 12)	X[-2] = 하정우, X[-1] = 전지현, X[1] = 조진웅
# (0.7644, 12)	X[-2] = 하정우, X[-1] = 전지현, X[1] = 오달수
# (0.7087, 12)	X[-2] = 강동원, X[-1] = 송강호, X[1] = 연기
# (0.951, 12)	X[-2] = 강동원, X[-1] = 김윤석, X[1] = 연기
# (0.8421, 12)	X[-2] = 황정민, X[-1] = 강동원, X[1] = 이성민
# (0.7257, 12)	X[-2] = 역시, X[-1] = 믿고보는, X[1] = 송강호
# (0.9755, 12)	X[-2] = 범인, X[-1] = 은, X[1] = 씨
# (0.8823, 12)	X[-2] = 관람, X[-1] = 객, X[1] = 테론
# (0.7879, 11)	X[-2] = ㅋㅋㅋ, X[-1] = ㅋ, X[1] = 님
# (0.7824, 11)	X[-2] = 영화, X[-1] = 다, X[1] = 씨의
# (0.9291, 11)	X[-2] = 좋았, X[-1] = 습니다, X[1] = 씨의
# (0.8341, 11)	X[-2] = 하정우, X[-1] = 씨와, X[1] = 씨의
# (0.8185, 11)	X[-2] = 하정우, X[-1] = 씨와, X[1] = 씨
# (0.7834, 11)	X[-2] = 좋았, X[-1] = 다, X[1] = 씨
# (0.71, 11)	X[-2] = 습니다, X[-1] = 그리고, X[1] = 씨
# (0.9873, 11)	X[-2] = 영화, X[-1] = 입니다, X[1] = 씨가
# (0.9152, 11)	X[-2] = 그래, X[-1] = 도, X[1] = 씨의
# (0.7972, 11)	X[-2] = 영화, X[-1] = 봤습니다, X[1] = 씨
# (0.7432, 11)	X[-2] = 무엇, X[-1] = 보다, X[1] = 님
# (0.7049, 11)	X[-2] = 었습니다, X[-1] = 특히, X[1] = 씨
# (0.7759, 11)	X[-2] = 적, X[-1] = 입니다, X[1] = 씨
# (0.7564, 11)	X[-2] = 믿고보는, X[-1] = 하정우, X[1] = 오달수
# (0.8364, 11)	X[-2] = 객, X[-1] = 믿고보는, X[1] = 짱짱
# (0.9606, 11)	X[-2] = 황정민, X[-1] = 이정재, X[1] = 연기
# (0.8291, 11)	X[-1] = 황정민, X[1] = 님
# (0.7439, 11)	X[-2] = 하정우, X[-1] = 존멋, X[1] = 존예
# (0.8074, 11)	X[-1] = 믿고보는, X[1] = 송강호
# (0.8161, 11)	X[-2] = 하정우, X[-1] = 김윤석, X[1] = 연기
# (0.9072, 11)	X[-2] = 믿고보는, X[-1] = 송강호, X[1] = 유아인
# (0.826, 10)	X[-2] = 김윤석, X[-1] = 님과, X[1] = 님
# (0.77, 10)	X[-2] = 최고, X[-1] = 였어요, X[1] = 씨
# (0.8545, 10)	X[-2] = 연기, X[-1] = 와, X[1] = 님의
# (0.7669, 10)	X[-2] = 다, X[-1] = 특히, X[1] = 씨
# (0.7439, 10)	X[-2] = 특, X[-1] = 히나, X[1] = 씨의
# (0.9131, 10)	X[-2] = 봤습니다, X[-1] = 특히, X[1] = 씨
# (0.8477, 10)	X[-2] = 개인적, X[-1] = 으로, X[1] = 씨가
# (0.7362, 10)	X[-2] = 이, X[-1] = 었어요, X[1] = 씨
# (0.7785, 10)	X[-2] = 믿고, X[-1] = 보는, X[1] = 씨
# (0.8426, 10)	X[-2] = 없는, X[-1] = 영화, X[1] = 씨
# (0.7439, 10)	X[-2] = 객, X[-1] = 역쉬, X[1] = 짱
# (0.7439, 10)	X[-2] = 재밌, X[-1] = 었어요, X[1] = 씨의
# (0.7942, 10)	X[-2] = 도, X[-1] = 좋고, X[1] = 씨
# (0.8503, 10)	X[-2] = 객, X[-1] = 역시, X[1] = 연기짱
# (0.7257, 10)	X[-2] = 영화, X[-1] = 였어요, X[1] = 씨의
# (0.8825, 10)	X[-2] = 특히, X[-1] = 앤, X[1] = 의
# (0.7062, 10)	X[-2] = 었어요, X[-1] = 특히, X[1] = 씨
# (0.9203, 10)	X[-1] = 히스, X[1] = 연기
# (0.7816, 10)	X[-2] = 역시, X[-1] = 믿고보는, X[1] = 연기
# (0.7439, 10)	X[-2] = 솔직, X[-1] = 히, X[1] = 씨가
# (0.8434, 10)	X[-2] = 곽도원, X[-1] = 곽도원, X[1] = 곽도원
# (0.9489, 10)	X[-2] = 전지현, X[-1] = 이정재, X[1] = 조진웅
# (0.8093, 10)	X[-2] = ㅠㅠ, X[-1] = ㅠㅠ, X[1] = 씨
# (0.7439, 10)	X[-2] = 강동원, X[-1] = 씨랑, X[1] = 씨
# (0.8934, 10)	X[-2] = 강동원, X[-1] = 씨와, X[1] = 씨의
# (0.7266, 10)	X[-2] = 믿고보는, X[-1] = 황정민, X[1] = 연기
# (0.8004, 10)	X[-2] = 었습니다, X[-1] = 특히, X[1] = 씨의
# (0.8144, 10)	X[-2] = 강동원, X[-1] = 이랑, X[1] = 얼굴
# (0.9071, 10)	X[-2] = 객, X[-1] = 믿고보는, X[1] = 송강호
# (0.7875, 9)	X[-2] = 좋았어요, X[-1] = 특히, X[1] = 씨
# (0.8422, 9)	X[-1] = 역시, X[1] = 씨는
# (0.828, 9)	X[-1] = 믿고보는, X[1] = 형님
# (0.7632, 9)	X[-1] = 역시, X[1] = 느님
# (0.7264, 9)	X[-2] = 영화, X[-1] = 예요, X[1] = 씨
# (0.8759, 9)	X[-2] = 영화, X[-1] = 네요, X[1] = 씨의
# (0.7439, 9)	X[-2] = 인거, X[-1] = 같아요, X[1] = 씨
# (0.9529, 9)	X[-2] = 볼만, X[-1] = 합니다, X[1] = 씨
# (0.8151, 9)	X[-2] = 그래, X[-1] = 도, X[1] = 씨와
# (0.8031, 9)	X[-2] = 재밌, X[-1] = 다, X[1] = 씨
# (0.7439, 9)	X[-2] = 개인적, X[-1] = 으로, X[1] = 씨를
# (0.8477, 9)	X[-2] = 것, X[-1] = 같아요, X[1] = 씨의
# (0.8304, 9)	X[-2] = 잘, X[-1] = 하시네요, X[1] = 씨
# (0.7628, 9)	X[-2] = 연기, X[-1] = 잘하시고, X[1] = 씨
# (0.7439, 9)	X[-2] = 무엇, X[-1] = 보다, X[1] = 씨가
# (0.8074, 9)	X[-2] = 영화, X[-1] = 봤네요, X[1] = 씨
# (0.8401, 9)	X[-1] = 믿고보는, X[1] = 씨
# (0.8195, 9)	X[-2] = 관람, X[-1] = 객, X[1] = 의재
# (0.8779, 9)	X[-2] = 객, X[-1] = 믿고보는, X[1] = 씨
# (0.7288, 9)	X[-2] = 그리, X[-1] = 구, X[1] = 씨
# (0.7285, 9)	X[-1] = 히스, X[1] = 가
# (0.8074, 9)	X[-2] = 도, X[-1] = 좋았고, X[1] = 씨
# (0.7873, 9)	X[-2] = 있, X[-1] = 었어요, X[1] = 씨의
# (0.7762, 9)	X[-2] = 너무, X[-1] = 좋았어요, X[1] = 씨
# (0.7579, 9)	X[-1] = 믿고보는, X[1] = 연기
# (0.7012, 9)	X[-2] = 역시, X[-1] = 믿고보는, X[1] = 와
# (0.8554, 9)	X[-2] = 같, X[-1] = 습니다, X[1] = 씨의
# (0.8188, 9)	X[-2] = 이정재, X[-1] = 전지현, X[1] = 조진웅
# (0.7537, 9)	X[-2] = 전지현, X[-1] = 존예, X[1] = 존멋
# (0.8564, 9)	X[-2] = 연기력, X[-1] = 과, X[1] = 씨의
# (0.7439, 9)	X[-2] = 탑이, X[-1] = 랑, X[1] = 연기
# (0.7245, 9)	X[-1] = 김윤석, X[1] = 씨
# (0.7257, 9)	X[-2] = 였어요, X[-1] = 특히, X[1] = 씨
# (0.8372, 9)	X[-2] = 황정민, X[-1] = 그리고, X[1] = 의
# (0.8775, 9)	X[-2] = 었어요, X[-1] = ㅠㅠ, X[1] = 씨
# (0.9122, 9)	X[1] = 슈왈츠제네거
# (0.8151, 9)	X[-2] = 정우성, X[-1] = 황정민, X[1] = 곽도원
# (0.7439, 8)	X[-2] = 봤습니다, X[-1] = 그리고, X[1] = 씨
# (0.7248, 8)	X[-2] = 그래, X[-1] = 도, X[1] = 씨가
# (0.866, 8)	X[-2] = 적이, X[-1] = 었어요, X[1] = 씨
# (0.895, 8)	X[-2] = 남자, X[-1] = 지만, X[1] = 씨
# (0.8023, 8)	X[-2] = 볼만, X[-1] = 해요, X[1] = 씨
# (0.7439, 8)	X[-2] = ㅋㅋㅋ, X[-1] = ㅋㅋ, X[1] = 씨
# (0.8099, 8)	X[-2] = 보는, X[-1] = 배우, X[1] = 씨
# (0.8437, 8)	X[-2] = 재밌, X[-1] = 었어요, X[1] = 씨가
# (0.7338, 8)	X[-2] = 게, X[-1] = 봤어요, X[1] = 님
# (0.8067, 8)	X[-2] = 무엇, X[-1] = 보다, X[1] = 님의
# (0.7244, 8)	X[-2] = 손예진, X[-1] = 씨랑, X[1] = 씨
# (0.7594, 8)	X[-2] = 같아요, X[-1] = 특히, X[1] = 씨
# (0.8074, 8)	X[-2] = 사랑, X[-1] = 해요, X[1] = 씨
# (0.7598, 8)	X[-2] = 숙희, X[-1] = 와, X[1] = 의
# (0.8526, 8)	X[-2] = 진짫, X[-1] = 잘생겻고, X[1] = 너무
# (0.9583, 8)	X[-2] = 박보영, X[-1] = 씨와, X[1] = 씨
# (0.8029, 8)	X[-2] = 었어요, X[-1] = ㅎㅎ, X[1] = 씨
# (0.7723, 8)	X[-2] = 말할것도, X[-1] = 없고, X[1] = 씨
# (0.7359, 8)	X[-2] = 황정민, X[-1] = 씨랑, X[1] = 씨
# (0.7472, 8)	X[-2] = 황정민, X[-1] = 씨와, X[1] = 씨
# (0.9557, 8)	X[-2] = 좋았, X[-1] = 습니다, X[1] = 씨는
# (0.7006, 8)	X[-2] = 객, X[-1] = 믿고보는, X[1] = 표
# (0.9454, 8)	X[1] = 헤니
# (0.8922, 8)	X[-2] = 이, X[-1] = 남네요, X[1] = 씨
# (0.8806, 8)	X[-1] = 탑과, X[1] = 의
# (0.8091, 8)	X[-2] = 송강호, X[-1] = 와, X[1] = 콤비
# (0.9707, 8)	X[-2] = 와중, X[-1] = 에, X[1] = 잘생김
# (0.8401, 8)	X[-2] = 볼만, X[-1] = 했어요, X[1] = 씨
# (0.7966, 8)	X[-2] = 강동원, X[-1] = 황정민, X[1] = 이성민
# (0.7809, 8)	X[-2] = 믿고보는, X[-1] = 송강호, X[1] = 연기
# (0.8389, 8)	X[-2] = 알겠더, X[-1] = 라구요, X[1] = 씨
# (0.7439, 8)	X[-1] = 아놀드, X[1] = 형님
# (0.7838, 8)	X[-2] = 박보영, X[-1] = 이랑, X[1] = 연기
# (0.8677, 8)	X[-2] = 할리퀸, X[-1] = 이랑, X[1] = 랑
# (0.7961, 8)	X[-1] = 믿고보는, X[1] = 유아인
# (0.9897, 8)	X[-1] = 니콜라스, X[1] = 진짜
# (0.7406, 8)	X[-1] = 브래드, X[1] = 가
# (0.8544, 7)	X[-2] = 좋, X[-1] = 습니다, X[1] = 씨
# (0.8433, 7)	X[-2] = 영화, X[-1] = 특히, X[1] = 씨
# (0.8487, 7)	X[-2] = 좋고, X[-1] = 특히, X[1] = 씨
# (0.7976, 7)	X[-2] = 있, X[-1] = 었습니다, X[1] = 씨의
# (0.7439, 7)	X[-2] = 재밌, X[-1] = 어요, X[1] = 씨가
# (0.7056, 7)	X[-2] = 멋, X[-1] = 지고, X[1] = 씨
# (0.8606, 7)	X[-1] = 역시, X[1] = 씨의
# (0.8515, 7)	X[-2] = 의외, X[-1] = 로, X[1] = 씨
# (0.9083, 7)	X[-2] = 좋았고, X[-1] = 특히, X[1] = 씨
# (0.7339, 7)	X[-2] = 하정우, X[-1] = 한석규, X[1] = 류승범
# (0.8231, 7)	X[-2] = 재미, X[-1] = 있었네요, X[1] = 씨
# (0.857, 7)	X[-1] = 역시, X[1] = 류승범
# (0.974, 7)	X[-2] = 습니다, X[-1] = 그리고, X[1] = 씨의
# (0.9075, 7)	X[-2] = 잘, X[-1] = 봤습니다, X[1] = 씨가
# (0.7439, 7)	X[-2] = 기대, X[-1] = 합니다, X[1] = 씨
# (0.703, 7)	X[-2] = 영화, X[-1] = 였습니다, X[1] = 씨는
# (0.8788, 7)	X[-2] = 역시, X[-1] = 믿고보는, X[1] = 짱
# (0.7006, 7)	X[-2] = 객, X[-1] = 믿고보는, X[1] = 연기력
# (0.8715, 7)	X[-2] = 너무, X[-1] = 재밌고, X[1] = 씨
# (0.7439, 7)	X[-2] = 역시, X[-1] = 믿고보는, X[1] = 씨
# (0.7173, 7)	X[-1] = 그냥, X[1] = 씨
# (0.753, 7)	X[-2] = 역시, X[-1] = 믿고보는, X[1] = 짱짱
# (0.7021, 7)	X[-2] = 객, X[-1] = 역쉬, X[1] = 연기
# (0.7716, 7)	X[-2] = 재밌, X[-1] = 었습니다, X[1] = 씨가
# (0.7338, 7)	X[-2] = 최고, X[-1] = 였습니다, X[1] = 씨
# (0.8977, 7)	X[-2] = 게, X[-1] = 봤습니다, X[1] = 씨가
# (0.9071, 7)	X[-2] = 객기, X[-1] = 승전, X[1] = 이
# (0.7386, 7)	X[-2] = 재미, X[-1] = 있어요, X[1] = 씨의
# (0.7771, 7)	X[-1] = 앤, X[1] = 와
# (0.7439, 7)	X[-2] = 김남길, X[-1] = 씨와, X[1] = 씨
# (0.8867, 7)	X[-2] = 관람, X[-1] = 객, X[1] = 씨연
# (0.8247, 7)	X[-2] = ㅠ, X[-1] = ㅠ, X[1] = 씨
# (0.8193, 7)	X[-2] = 역시, X[-1] = 나, X[1] = 씨
# (0.8092, 7)	X[-2] = 네요, X[-1] = 아무튼, X[1] = 씨
# (0.8087, 7)	X[-2] = 영화, X[-1] = 였습니다, X[1] = 씨가
# (0.7257, 7)	X[-2] = 그나저, X[-1] = 나, X[1] = 씨
# (0.9152, 7)	X[-2] = 영화, X[-1] = 특히, X[1] = 씨의
# (0.9591, 7)	X[-2] = 하정우, X[-1] = 와, X[1] = 배두나
# (0.9446, 7)	X[-2] = 역시, X[-1] = 믿고보는, X[1] = 연기력
# (0.9419, 7)	X[-2] = 영화, X[-1] = 입니다, X[1] = 씨와
# (0.7439, 7)	X[-2] = 게, X[-1] = 봤습니다, X[1] = 씨의
# (0.7866, 7)	X[-2] = 게, X[-1] = 잘봤어요, X[1] = 씨
# (0.8713, 7)	X[-2] = 않았, X[-1] = 고, X[1] = 씨
# (0.9581, 7)	X[-1] = 믿고보는, X[1] = 최민식
# (0.9121, 7)	X[-2] = 영화, X[-1] = 역시, X[1] = 형님
# (0.7439, 7)	X[-2] = 대박, X[-1] = 입니다, X[1] = 씨
# (0.9388, 7)	X[-2] = 하정우, X[-1] = 이정재, X[1] = 조진웅
# (0.7884, 7)	X[-2] = 이정재, X[-1] = 하정우, X[1] = 오달수
# (0.7418, 7)	X[-2] = 것, X[-1] = 같네요, X[1] = 씨
# (0.8902, 7)	X[-2] = 잘하시고, X[-1] = 특히, X[1] = 씨
# (0.8343, 7)	X[-2] = 송강호, X[-1] = 역시, X[1] = 연기
# (0.8713, 7)	X[-2] = 최고, X[-1] = 에요, X[1] = 씨
# (0.7125, 7)	X[-2] = 황정민, X[-1] = 강동원, X[1] = 콤비
# (0.7359, 7)	X[-2] = 객, X[-1] = 황정민, X[1] = 님
# (0.889, 7)	X[-2] = 객, X[-1] = 역시, X[1] = 오빠
# (0.8228, 7)	X[-2] = 너무, X[-1] = 재밌네요, X[1] = 씨
# (0.9822, 7)	X[1] = 파렐
# (0.8821, 7)	X[-2] = 감우성, X[-1] = 정진영, X[1] = 연기
# (0.8967, 7)	X[-2] = 공유, X[-1] = 와, X[1] = 씨
# (0.8926, 7)	X[-2] = 역시, X[-1] = 믿고보는, X[1] = 공유
# (0.7244, 7)	X[-2] = 김명민, X[-1] = 씨와, X[1] = 씨의
# (0.8342, 7)	X[-1] = 월, X[1] = 의
# (0.7244, 7)	X[-2] = 황정민, X[-1] = 곽도원, X[1] = 주지훈
# (0.9086, 7)	X[-1] = 니콜라스, X[1] = 를
# (0.7158, 7)	X[-2] = 그런지, X[-1] = 니콜라스, X[1] = 와의
# (0.9796, 7)	X[-1] = 니콜라스, X[1] = 와
# (0.9745, 7)	X[-1] = 니콜라스, X[1] = 는
# (0.7344, 7)	X[-1] = 한석규, X[1] = 오달수
# (0.7551, 7)	X[-1] = 역시, X[1] = 안성기
# (0.7995, 6)	X[-1] = 역시, X[1] = 님의
# (0.8862, 6)	X[-2] = 송강호, X[-1] = 씨랑, X[1] = 씨
# (0.877, 6)	X[-2] = 습니다, X[-1] = 특히, X[1] = 씨의
# (0.8713, 6)	X[-2] = 적이, X[-1] = 였어요, X[1] = 씨
# (0.9764, 6)	X[-2] = 멋, X[-1] = 있어요, X[1] = 씨
# (0.9061, 6)	X[-2] = 영화, X[-1] = 였어요, X[1] = 씨도
# (0.8477, 6)	X[-2] = 김윤석, X[-1] = 과, X[1] = 연기
# (0.8551, 6)	X[-2] = 아쉬운, X[-1] = 건, X[1] = 씨가
# (0.9583, 6)	X[-2] = ㅎㅎ, X[-1] = 특히, X[1] = 씨
# (0.7977, 6)	X[-2] = 한석규, X[-1] = 하정우, X[1] = 류승범
# (0.9107, 6)	X[-2] = 볼만, X[-1] = 했음, X[1] = 씨
# (0.7439, 6)	X[-2] = 거에, X[-1] = 요, X[1] = 씨
# (0.7439, 6)	X[-1] = 역시, X[1] = 씨가
# (0.7574, 6)	X[-2] = 보고, X[-1] = 왔습니다, X[1] = 씨의
# (0.7085, 6)	X[-2] = 었어요, X[-1] = 그리고, X[1] = 씨
# (0.7655, 6)	X[-2] = 관람, X[-1] = 객, X[1] = 씨랑
# (0.9355, 6)	X[-2] = 보았습니, X[-1] = 다, X[1] = 씨의
# (0.7107, 6)	X[-2] = 객잘, X[-1] = 봤습니다, X[1] = 씨
# (0.7785, 6)	X[-2] = 영화, X[-1] = 같네요, X[1] = 씨
# (0.8713, 6)	X[-2] = 게, X[-1] = 잘봤어요, X[1] = 님
# (0.8464, 6)	X[-1] = 본격, X[1] = 입덕영화
# (0.8946, 6)	X[-2] = 객, X[-1] = 믿고보는, X[1] = 님
# (0.7525, 6)	X[-2] = 사랑, X[-1] = 해요, X[1] = 님
# (0.7342, 6)	X[-2] = 요, X[-1] = ㅎㅎ, X[1] = 씨
# (0.9146, 6)	X[-2] = 재밌, X[-1] = 었어요, X[1] = 씨는
# (0.9706, 6)	X[-2] = 김남길, X[-1] = 씨와, X[1] = 씨의
# (0.7631, 6)	X[-2] = 봤네요, X[-1] = 특히, X[1] = 씨
# (0.8761, 6)	X[-2] = 재밌, X[-1] = 었어요, X[1] = 씨도
# (0.8687, 6)	X[-2] = 게, X[-1] = 봤어요, X[1] = 씨의
# (0.7439, 6)	X[-2] = 보고, X[-1] = 왔네요, X[1] = 씨
# (0.9601, 6)	X[-2] = 지네, X[-1] = 요, X[1] = 씨
# (0.719, 6)	X[-2] = 연기, X[-1] = 특히, X[1] = 연기
# (0.7439, 6)	X[-2] = 봤, X[-1] = 는데, X[1] = 씨의
# (0.7043, 6)	X[-1] = 자레드, X[1] = 조커
# (0.7966, 6)	X[-2] = 박보영, X[-1] = 과, X[1] = 연기
# (0.8683, 6)	X[-2] = 재밌, X[-1] = 어요, X[1] = 씨도
# (0.8883, 6)	X[-1] = 믿고보는, X[1] = 정우
# (0.8604, 6)	X[-2] = 하정우, X[-1] = 랑, X[1] = 캐미
# (0.9656, 6)	X[-2] = 영화, X[-1] = 역시, X[1] = 오달수
# (0.824, 6)	X[-2] = 믿고, X[-1] = 보는, X[1] = 배두나
# (0.814, 6)	X[-2] = 객, X[-1] = 역시, X[1] = 배두나
# (0.8965, 6)	X[-2] = 믿고보는, X[-1] = 하정우, X[1] = 배두나
# (0.9583, 6)	X[-2] = 역시, X[-1] = 명불허전, X[1] = 연기
# (0.7965, 6)	X[-2] = 있게, X[-1] = 잘봤어요, X[1] = 씨
# (0.7593, 6)	X[-2] = 주연, X[-1] = 배우, X[1] = 씨의
# (0.8934, 6)	X[-1] = 믿고보는, X[1] = 아저씨
# (0.7691, 6)	X[-2] = 황정민, X[-1] = 이정재, X[1] = 박성웅
# (0.761, 6)	X[-2] = 게다, X[-1] = 가, X[1] = 씨
# (0.7439, 6)	X[-2] = 봤어요, X[-1] = 특히, X[1] = 씨
# (0.8182, 6)	X[-2] = 기도, X[-1] = 좋았지만, X[1] = 씨
# (0.8547, 6)	X[-2] = 처음, X[-1] = 이네요, X[1] = 씨
# (0.7843, 6)	X[-1] = 대박, X[1] = 씨
# (0.7697, 6)	X[-2] = 겠어, X[-1] = 요, X[1] = 씨
# (0.7439, 6)	X[-2] = 울었, X[-1] = 다, X[1] = 씨
# (0.8074, 6)	X[-2] = 갔, X[-1] = 는데, X[1] = 씨
# (0.7968, 6)	X[-2] = 유아인, X[-1] = 씨와, X[1] = 씨의
# (0.8996, 6)	X[-1] = 다케우치, X[1] = 의
# (0.7354, 6)	X[-2] = 탑이, X[-1] = 랑, X[1] = 랑
# (0.7658, 6)	X[-2] = 영화, X[-1] = 앤, X[1] = 의
# (0.7732, 6)	X[-1] = 앤, X[1] = 연기
# (0.7812, 6)	X[-1] = 로버트, X[1] = 짱
# (0.9586, 6)	X[-2] = 송강호, X[-1] = 씨와, X[1] = 씨
# (0.7413, 6)	X[-2] = 기억에, X[-1] = 남는건, X[1] = 엉덩이
# (0.7295, 6)	X[-2] = 영화, X[-1] = 역시, X[1] = 씨
# (0.8436, 6)	X[-2] = 입니다, X[-1] = 특히, X[1] = 씨
# (0.7794, 6)	X[-2] = 이병헌, X[-1] = 씨와, X[1] = 씨의
# (0.8885, 6)	X[-2] = 이병헌, X[-1] = 씨와, X[1] = 씨
# (0.9387, 6)	X[-2] = 적이, X[-1] = 고, X[1] = 씨의
# (0.7439, 6)	X[-2] = 잘, X[-1] = 봤습니다, X[1] = 씨도
# (0.8689, 6)	X[-1] = 배우, X[1] = 씨가
# (0.9649, 6)	X[-2] = 믿고보는, X[-1] = 황정민, X[1] = 짱
# (0.8756, 6)	X[-2] = 황정민, X[-1] = 이랑, X[1] = 케미
# (0.7929, 6)	X[-2] = 객, X[-1] = 황정민, X[1] = 씨
# (0.9351, 6)	X[-2] = 영화, X[-1] = 였습니다, X[1] = 씨와
# (0.8749, 6)	X[-2] = 들, X[-1] = 었어요, X[1] = 씨의
# (0.8298, 6)	X[-2] = 한효주, X[-1] = 씨와, X[1] = 씨의
# (0.9756, 6)	X[-2] = 김명민, X[-1] = 발견, X[1] = 김동완
# (0.7185, 6)	X[-1] = ㅎㅎ, X[1] = 씨
# (0.8221, 6)	X[-2] = 황정민, X[-1] = 정우성, X[1] = 곽도원
# (0.7867, 6)	X[-2] = 할리퀸, X[-1] = 이랑, X[1] = 때문
# (0.7765, 6)	X[-2] = 유아인, X[-1] = 황정민, X[1] = 오달수
# (0.9233, 6)	X[-2] = 특히, X[-1] = 니콜라스, X[1] = 의
# (0.8612, 6)	X[-2] = 아, X[-1] = 힘내, X[1] = 씨
# (0.8597, 6)	X[-2] = 믿고보는, X[-1] = 황정민, X[1] = 정우
# (0.7439, 5)	X[-2] = 기대, X[-1] = 되요, X[1] = 씨
# (0.7439, 5)	X[-2] = 고, X[-1] = 특히, X[1] = 씨
# (0.7768, 5)	X[-2] = 객, X[-1] = 역쉬, X[1] = 씨
# (0.7542, 5)	X[-2] = 좋았, X[-1] = 다, X[1] = 씨의
# (0.7134, 5)	X[-2] = 추천, X[-1] = 합니다, X[1] = 씨
# (0.8104, 5)	X[-2] = 생각, X[-1] = 보다, X[1] = 씨의
# (0.7651, 5)	X[-2] = ㅋㅋ, X[-1] = 그리고, X[1] = 씨
# (0.7002, 5)	X[-2] = 이, X[-1] = 거보고, X[1] = 씨
# (0.7116, 5)	X[-2] = 이, X[-1] = 였어요, X[1] = 씨
# (0.7949, 5)	X[-2] = 영화, X[-1] = 였다, X[1] = 씨의
# (0.9019, 5)	X[-2] = 봤네요, X[-1] = 역시, X[1] = 님
# (0.7626, 5)	X[-2] = 재미, X[-1] = 있었음, X[1] = 씨
# (0.855, 5)	X[-1] = 사실, X[1] = 씨
# (0.869, 5)	X[-2] = 한석규, X[-1] = 류승범, X[1] = 연기
# (0.8828, 5)	X[-2] = 좋았, X[-1] = 는데, X[1] = 씨
# (0.8217, 5)	X[-2] = 봤어요, X[-1] = ㅋㅋ, X[1] = 씨
# (0.8478, 5)	X[-2] = 류승범, X[-1] = 한석규, X[1] = 연기
# (0.7587, 5)	X[-1] = 믿고보는, X[1] = 믿고
# (0.9819, 5)	X[-2] = 하정우, X[-1] = 씨랑, X[1] = 씨
# (0.9351, 5)	X[-2] = 개인적, X[-1] = 으로, X[1] = 씨와
# (0.8308, 5)	X[-1] = 아, X[1] = 씨의
# (0.7631, 5)	X[-2] = 영화, X[-1] = 임, X[1] = 씨

# %% [markdown]
# 우리는 sparse vector representation 형태의 input data 를 만들었기 때문에 logistic regression 을 이용했습니다. 이와 다르게 X[-2], X[-1], X[1], X[2] 의 단어의 word vector 를 concatenation 한다면 neural network 의 input 이 될 수 있습니다. 이러한 방식이 아래의 Stanford 수업의 assignment 내용입니다.
#
# https://nlp.stanford.edu/~socherr/pa4_ner.pdf
#
# 또한 word vector 를 이용한다면 Convolutional Neural Network (CNN) 를 이용할 수도 있습니다. 특히나 CNN 은 n-gram features 를 이용하기 때문에 문맥 정보가 더 정확히 잡힐 수 있습니다. 이에 대해서는 다른 튜토리얼에서 다룹니다.
