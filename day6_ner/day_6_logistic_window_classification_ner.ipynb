# %% [markdown]
# ## 주의
#
# 이 tutorials 는 큰 용량의 메모리를 요구합니다. 충분한 메모리가 확보된 각자의 환경에서만 테스트 해보시길 권장합니다.
#
# Scikit-learn 의 logistic regression 을 이용하기 위하여 데이터를 한 번에 메모리에 올리기 때문인데, 대략 6 GB 를 이용합니다.
#
# Scikit-learn 에서도 partial fit 함수를 이용하여 mini batch style 을 구현할 수 있습니다. Scikit-learn 은 근사 해법들이 잘 구현되어 있습니다. 혹은 PyTorch 나 TensorFlow 를 이용하여 네트워크를 구성하셔도 좋습니다. 이 때는 근사 해법들은 따로 구현하셔야 합니다.

# %% [markdown]
# ## Load dataset
#
# Comments 는 list of str 형식의 문장을 yield 하는 데이터클래스 입니다. 영화평 데이터는 (영화 id, 영화평, 평점) 의 column data 이기 때문에 영화평만 선택하여 띄어쓰기 기준으로 split 합니다.

# %%
import config
from navermovie_comments import get_movie_comments_path

class Comments:
    def __init__(self, path):
        self.path = path

    def __iter__(self):
        def normalize(text):
            if text[:3] == '관람객':
                return text[3:].strip()
            return text

        with open(self.path, encoding='utf-8') as f:
            for i, doc in enumerate(f):
                idx, text, rate = doc.split('\t')
                yield normalize(text).split()

path = get_movie_comments_path(large=True, tokenize='soynlp_unsup')
sents = [sent for sent in Comments(path)]

for i, sent in enumerate(sents):
    if i >= 3:
        break
    print(sent)
# Out:
# soynlp=0.0.492
# added lovit_textmining_dataset
# ['명불허전']
# ['왠지', '고사', '피의', '중간', '고사', '보다', '재미', '가', '없을듯', '해요', '만약', '보게', '된다면', '실망', '할듯']
# ['티아라', '사랑', '해', 'ㅜ']

# %% [markdown]
# ## Scan vocabulary
#
# 데이터에 존재하는 단어들을 `min_count` 기준으로 필터링합니다. Return 값으로 vocabulary index 와 count 를 return 합니다.

# %%
from collections import defaultdict

def scan_vocabulary(sents, min_count, verbose=False):
    counter = defaultdict(int)
    for i, sent in enumerate(sents):
        if verbose and i % 100000 == 0:
            print('\rscanning vocabulary .. from %d sents' % i, end='')
        for word in sent:
            counter[word] += 1
    counter = {word:count for word, count in counter.items()
               if count >= min_count}
    idx_to_vocab = [vocab for vocab in sorted(counter,
                    key=lambda x:-counter[x])]
    vocab_to_idx = {vocab:idx for idx, vocab in enumerate(idx_to_vocab)}
    idx_to_count = [counter[vocab] for vocab in idx_to_vocab]
    if verbose:
        print('\rscanning vocabulary was done. %d terms from %d sents' % (len(idx_to_vocab), i+1))
    return vocab_to_idx, idx_to_vocab, idx_to_count

vocab_to_idx, idx_to_vocab, idx_to_count = scan_vocabulary(
    sents, min_count=10, verbose=True)
# Out:
# scanning vocabulary was done. 69541 terms from 3280685 sents

# %% [markdown]
# scan_vocabulary 의 return 값을 살펴봅니다.

# %%
print(idx_to_vocab[:5])
print(idx_to_count[:5])
# Out:
# ['영화', '이', '관람', '객', '의']
# [1128809, 866305, 600351, 526070, 489950]

# %% [markdown]
# ## Word2Vec 을 이용한 seed set 만들기
#
# 미리 학습해둔 Word2Vec model 을 로딩합니다. 우리는 사람 이름을 인식하는 named entity recognizer 를 만들겁니다. `송강호`와 `디카프리오`의 Word2Vec 유사어는 사람 이름임을 알 수 있습니다. 각각 100 개씩의 유사어를 선택하여 이의 합집합을 seed_words 로 선택합니다. 총 172 개의 단어가 seeds 로 선택되었습니다.

# %%
from pprint import pprint
from navermovie_comments import load_trained_embedding


word2vec = load_trained_embedding(tokenize='soynlp_unsup')

pprint(word2vec.wv.most_similar('송강호', topn=10))
pprint(word2vec.wv.most_similar('디카프리오', topn=10))

seed_words = {word for word, _ in word2vec.most_similar('송강호', topn=100)}
seed_words.update({word for word, _ in word2vec.most_similar('디카프리오', topn=100)})

len(seed_words)
# Out:
# [('하정우', 0.9089709520339966),
#  ('한석규', 0.882610023021698),
#  ('오달수', 0.8565835356712341),
#  ('이정재', 0.8554919362068176),
#  ('김명민', 0.8462209105491638),
#  ('이범수', 0.8421300649642944),
#  ('설경구', 0.8421212434768677),
#  ('황정민', 0.8380463719367981),
#  ('손현주', 0.8376869559288025),
#  ('김윤석', 0.8338450193405151)]
# [('레오', 0.8400799036026001),
#  ('톰하디', 0.8309459686279297),
#  ('앤해서웨이', 0.775414764881134),
#  ('앤헤서웨이', 0.7646037340164185),
#  ('브래드피트', 0.7506041526794434),
#  ('로다주', 0.7499849796295166),
#  ('로버트드니로', 0.7493538856506348),
#  ('콜린퍼스', 0.7378235459327698),
#  ('히스레저', 0.7330209612846375),
#  ('윌스미스', 0.7309495806694031)]
# /home/lovit/anaconda3/envs/pytorch/lib/python3.7/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# /home/lovit/anaconda3/envs/pytorch/lib/python3.7/site-packages/ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   # Remove the CWD from sys.path while we load stuff.
# /home/lovit/anaconda3/envs/pytorch/lib/python3.7/site-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   # This is added back by InteractiveShellApp.init_path()
# 172

# %% [markdown]
# ## Features
#
# 우리는 window = 2 를 이용하여 한 단어 X[0] 의 앞, 뒤 각각 두 개의 단어 (총 4개의 단어)를 X[0] 의 features 로 이용합니다. 예를 들어 (a, b, c, d, e) 라는 단어가 등장하였고, X[0]=c 라면 X[-2]=a, X[-1]=b, X[1]=d, X[2]=e 입니다.
#
# 그리고 scan vocabulary 함수를 통하여 학습된 단어가 총 5 개라면 이들의 위치를 보존하면 X[0] 에 대한 feature space 를 20 만 차원으로 만들 수 있습니다. 만약 각 단어의 index 가 {a:0, b:1, c:2, d:3, e:4} 라면 X[0]=c 는 [0, 5+1, 10+3, 15+4] 를 features 로 가진다 표현할 수 있습니다.
#
# feature_to_idx 는 이를 만드는 함수입니다. 문장 내에서 현재 단어 X[0] 의 위치를 i, 현재 단어 앞, 뒤 단어인 X[-1] 이나 X[1] 의 위치를 j, j 위치의 단어의 index 를 vocab_idx 라 할 때, 이 값의 feature index 를 출력합니다.

# %%
def feature_to_idx(i, j, vocab_idx, window, n_terms):
    if j < i:
        return n_terms * (j - i + window) + vocab_idx
    else:
        return n_terms * (j - i + window - 1) + vocab_idx

feature_to_idx(i=2, j=3, vocab_idx=3, window=2, n_terms=5)
# Out:
# 13

# %% [markdown]
# idx_to_feature 는 반대로 feature index 를 feature 로 decode 합니다. feature idx 를 vocabulary 의 개수로 나눈 몫은 상대적 위치값이 되고, 나머지는 vocabulary idx 입니다.

# %%
def idx_to_feature(feature_idx, idx_to_vocab, window):
    # 몫
    position = feature_idx // len(idx_to_vocab)
    if position < window:
        feature = 'X[-%d] = ' % (window - position)
    else:
        feature = 'X[%d] = ' % (position - window + 1)
    # 나머지
    vocab_idx = feature_idx % len(idx_to_vocab)
    feature += idx_to_vocab[vocab_idx]
    return feature

idx_to_feature(13, 'a b c d e'.split(), window=2)
# Out:
# 'X[1] = d'

# %% [markdown]
# 이를 이용하여 학습데이터로부터 window classification 용 데이터를 만듭니다. X[0] 을 기준으로 X[-2], X[-1], X[1], X[2] 의 co-occurrence 를 계산하는 matrix 를 만듭니다. Sparse matrix 형식이기 때문에 rows, columns 를 따로 모읍니다. words 는 각 rows 에 해당하는 단어를 넣어둡니다.
#
# 아래 부분에서 scan vocabulary 의 결과에 포함되지 않은 단어는 건너 띄며, context words 의 범위는 문장의 맨 앞에서 문장의 맨 뒷 단어가 되도록 index 의 범위를 확인합니다.
#
# ```python
# for i, word in enumerate(sent):
#     if not (word in vocab_to_idx):
#         continue
#
#     b = max(0, i - window)
#     e = min(i + window, n_words)
# ```
#
# 아래 구문을 통하여 sent[j] 의 단어 역시 scan vocabulary 의 결과에 포함되지 않으면 이를 이용하지 않습니다.
#
# ```python
# for j in range(b, e):
#     if i == j:
#         continue
#     j_idx = vocab_to_idx.get(sent[j], -1)
#     if j_idx == -1:
#         continue
# ```

# %%
import numpy as np
from scipy.sparse import csr_matrix

def create_dataset(vocab_to_idx, sentences, seed_words, window=2, test_data=False, verbose=True):

    def contain_seed(sent):
        for word in sent:
            if word in seed_words:
                return True
        return False

    n_terms = len(vocab_to_idx)

    rows = []
    cols = []
    words = []

    row_idx = 0
    col_idx = window * 2 * n_terms

    for i_sent, sent in enumerate(sentences):

        if verbose and i_sent % 10000 == 0:
            print('\rcreating train dataset {} rows from {} sents'.format(row_idx, i_sent), end='')

        if (not test_data) and (not contain_seed(sent)):
            continue

        n_words = len(sent)

        for i, word in enumerate(sent):
            if not (word in vocab_to_idx):
                continue

            b = max(0, i - window)
            e = min(i + window + 1, n_words)

            features = []
            for j in range(b, e):
                if i == j:
                    continue
                j_idx = vocab_to_idx.get(sent[j], -1)
                if j_idx == -1:
                    continue
                features.append(feature_to_idx(i, j, j_idx, window, n_terms))

            if not features:
                continue

            # sparse matrix element
            for col in features:
                rows.append(row_idx)
                cols.append(col)

            # words element
            words.append(word)

            row_idx += 1

    if verbose:
        print('\rtrain dataset {} rows from {} sents was created    '.format(row_idx, i_sent))

    # to csr matrix
    rows = np.asarray(rows, dtype=np.int)
    cols = np.asarray(cols, dtype=np.int)
    data = np.ones(rows.shape[0], dtype=np.int)
    X = csr_matrix((data, (rows, cols)), shape=(row_idx, col_idx))

    return X, words

# %%
X_train, words = create_dataset(vocab_to_idx, sents, seed_words, window=2, test_data=False)
# Out:
# train dataset 5217933 rows from 3280684 sents was created

# %% [markdown]
# ## Word2Vec 유사어를 이용하여 label vector 만들기
#
# 앞서 만든 X 의 row 에 해당하는 단어가 seed_words 에 포함될 경우, 이 rows 의 값을 1 로, 그렇지 않은 경우 0 으로 지정합니다.
#
# 172 개의 단어가 361,394 번 등장하였습니다.

# %%
y_train = np.zeros(X_train.shape[0], dtype=np.int)
for i, word in enumerate(words):
    if word in seed_words:
        y_train[i] = 1

y_train.sum()
# Out:
# 361749

# %% [markdown]
# ## Logistic Regression 을 이용한 window classifier 만들기
#
# Logistic regression 을 학습합니다. seed words 를 positive class 로 예측하는 모델을 만듭니다. 그런데 실제로는 사람 이름이면서도 label 을 0 으로 가지는 데이터도 존재합니다. Logistic regression 은 이들에 대해서는 큰 확률값을 지닐 가능성이 높습니다. Training error 를 named entity 의 힌트로 이용하는 것입니다. 이 때의 training error 는 우리가 seed words 를 이용하여 엉성하게 데이터를 준비했기 때문에 발생하는 error 이기 때문입니다.

# %%
from sklearn.linear_model import LogisticRegression

logistic = LogisticRegression()
logistic.fit(X_train, y_train)
# Out:
# /home/lovit/anaconda3/envs/pytorch/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %% [markdown]
# 학습에 이용한 X_train 은 크기가 그렇게 큰 편은 아니지만, 모든 문장을 prediction 을 위한 sparse matrix 로 변환하면 그 크기는 상당히 큽니다. 약 20 GB 의 메모리가 필요했습니다. 이런 경우에는 `batch_sents_size` 씩 테스트 문장을 잘라내어 데이터를 만든 뒤, prediction 결과만 따로 저장합니다. 일종의 minibatch 형식입니다.
#
# 다음 `day7_3_feedforward_window_classification_ner` 에서는 학습 과정도 Scikit-learn 을 이용한 minibatch 형식으로 구현해 봅니다.

# %%
import math

def minibatch_predict(sents, seed_words, model, batch_sents_size=100000):

    # prepare
    y_prob = []
    y_words = []
    n_sents = len(sents)
    n_batchs = math.ceil(n_sents / batch_sents_size)

    # for each batch
    for batch in range(n_batchs):

        # begin, end index
        b = batch * batch_sents_size
        e = min((batch + 1) * batch_sents_size, n_sents)

        # slicing list & create dataset
        batch_sents = sents[b:e]
        X, words = create_dataset(vocab_to_idx, batch_sents, seed_words, test_data=True, verbose=False)

        # append prediction probability & label word
        y_prob.append(model.predict_proba(X))
        y_words += words

        # verbose
        print('\rbatch prediction {} / {}'.format(batch+1, n_batchs), end='')
    print('\rbatch prediction {0} / {0}'.format(n_batchs))

    # merging stacked numpy.ndarray
    y_prob = np.vstack(y_prob)[:,1]
    # transform list of str to numpy.ndarray of str
    y_words=  np.asarray(y_words)

    return y_prob, y_words

y_prob, y_words = minibatch_predict(sents, seed_words, logistic)
# Out:
# batch prediction 33 / 33

# %% [markdown]
# 총 43,000,283 개의 prediction 을 하였습니다.

# %%
y_prob.shape, y_words.shape
# Out:
# ((43000283,), (43000283,))

# %% [markdown]
# Softmax regression 은 일단 학습데이터로부터 패턴을 학습하기 때문에 positive class 에는 큰 확률을, negative class 에는 작은 확률을 부여합니다. 하지만 여기에는 실제로 positive class 이지만, 우리가 label 을 negative 로 준 경우도 있습니다. Positive 의 개수가 negative 보다 작기 때문에 모델은 positive class 를 더 잘 맞추는 쪽으로 학습을 합니다 (Scikit-learn 은 loss 의 class weight 를 조정하는게 기본값입니다). 그렇기 때문에 실제로 positive 이나 negative 로 label 된 경우에는 training error 가 크게 났을 것입니다.
#
# 그리고 그 영향력이 적다 하더라도 실제로 positive 인데 negative 로 labeling 된 데이터에 의하여 positive 에 해당하는 데이터들의 확률도 1 보다는 작은 값에 가까워집니다. 그렇기 때문에 우리는 여유롭게 positive class 의 확률값이 0.3 보다 큰 경우들을 세어봅니다.
#
# 예를 들어 배우 `백윤식` 은 seed words 에 포함되지 않았지만 총 100 번 등장하였고, 그 중 95 번을 0.05 보다 큰 prediction probability 를 받았다면, 이 단어의 named entity score 는 0.95 가 됩니다.

# %%
from collections import Counter

# word count
word_counter = Counter(y_words)

# prediction count
pred_pos = defaultdict(int)
for row in np.where(y_prob >= 0.3)[0]:
    pred_pos[y_words[row]] += 1
pred_pos = {word:pos/word_counter[word] for word, pos in pred_pos.items()}

# %% [markdown]
# ## 결과 확인하기
#
# Named entity score 가 큰 순서대로 상위 1000 개의 단어를 선택합니다. 그 중 seed words 에 포함된 단어는 출력하지 않습니다. (단어, 빈도수), score 를 확인합니다. 실제로 `엔헤서웨이` 가 띄어쓰기 된 `헤서웨이` 은 261 번 등장했으며, 약 233 번 0.3 보다 큰 probability 를 얻었습니다.
#
# 배우 `유해진`은 삼시 세끼 이후 `참바다`라는 별명을 얻게 되었는데, 영화평에서도 이 단어가 배우 이름으로 이용됨을 알 수 있습니다.

# %%
for word, prob in sorted(pred_pos.items(), key=lambda x:-x[1])[:1000]:
    if word in seed_words:
        continue
    if word_counter[word] < 50:
        continue
    idx = vocab_to_idx[word]
    count = idx_to_count[idx]
    print('{} ({})\t{:.3f}'.format(word, count, prob))
# Out:
# 패틴슨 (286)	0.902
# 헤서웨이 (261)	0.893
# 고슬링 (195)	0.882
# 와저 (188)	0.851
# 보성이 (190)	0.842
# 종석 (183)	0.835
# ㅋㅋ이민기 (80)	0.825
# 보성 (411)	0.798
# 손혜진 (61)	0.787
# 진구씨 (171)	0.760
# 내생 (843)	0.758
# 류해진 (80)	0.750
# 보영 (636)	0.746
# 김래원 (3096)	0.736
# 김영민 (80)	0.725
# 감우성씨 (98)	0.724
# 태현 (58)	0.724
# 에바그린 (555)	0.723
# 제니퍼로렌스 (50)	0.720
# 우성이 (271)	0.720
# 자매간 (82)	0.720
# 에디레드메인 (66)	0.712
# 이재훈 (61)	0.705
# 라이언고슬링 (134)	0.701
# 레져 (78)	0.692
# 데이먼 (942)	0.686
# 보영이누나 (144)	0.685
# 최다니엘 (239)	0.684
# 참바다 (81)	0.679
# 지연누나 (198)	0.677
# 민희 (61)	0.672
# 민정 (68)	0.672
# 하이모어 (124)	0.669
# 염정아 (133)	0.669
# 애덤리바인 (108)	0.664
# 김아중 (2567)	0.663
# 부녀간 (65)	0.662
# 지현언니 (56)	0.661
# 강호 (147)	0.660
# 기동이 (1341)	0.655
# 오웬 (84)	0.655
# 표도르 (99)	0.646
# 조니뎁 (3071)	0.643
# 유승룡 (56)	0.643
# 남녀간 (164)	0.640
# 탑오빠 (75)	0.640
# 그냥말 (259)	0.637
# 원빈 (10765)	0.635
# 노아 (265)	0.634
# 한가인 (800)	0.633
# 동석 (98)	0.633
# 진격 (182)	0.632
# 애드워드 (130)	0.628
# 아중이 (145)	0.628
# 하울 (2337)	0.627
# 문채원 (292)	0.627
# 샤를리즈테론 (93)	0.624
# 현빈 (3658)	0.620
# 화담 (50)	0.620
# 허이재 (204)	0.616
# 이요원 (124)	0.613
# 이진욱 (369)	0.612
# 톰쿠르즈 (116)	0.612
# 제훈 (67)	0.612
# 이민정 (789)	0.612
# 제2 (595)	0.611
# 아미르칸 (73)	0.611
# 프레디하이모어 (74)	0.608
# 리한나 (84)	0.607
# 김새론 (71)	0.606
# 한지민 (2417)	0.605
# 지연언니 (135)	0.604
# 맷데이먼 (1165)	0.604
# 올랜도블룸 (53)	0.604
# 잠파노 (127)	0.603
# 강소라 (226)	0.602
# 일병 (220)	0.600
# 아중씨 (71)	0.600
# 로버트패틴슨 (167)	0.600
# 이기홍 (161)	0.596
# 니플러 (84)	0.595
# 전지연 (96)	0.594
# 동석이형 (123)	0.593
# 마쁜이 (91)	0.593
# 틸다스윈튼 (78)	0.592
# 비와 (127)	0.591
# 프리먼 (105)	0.590
# 보영이 (186)	0.589
# 쿠니무라준 (51)	0.588
# 안젤라베이비 (51)	0.588
# 아역들 (284)	0.588
# 김동욱 (128)	0.587
# 정민이 (92)	0.587
# 이동휘 (53)	0.585
# 고아성 (565)	0.584
# 로다쥬 (60)	0.583
# 장윤주씨 (62)	0.581
# 참바다씨 (131)	0.580
# 아중누나 (50)	0.580
# 박민하양 (64)	0.578
# 터너 (54)	0.577
# 변희봉 (137)	0.577
# 이성민씨 (59)	0.576
# 신혜 (92)	0.576
# 소희 (1293)	0.575
# 스칼렛요한슨 (148)	0.574
# 삼가고인 (162)	0.574
# 마이클베이감독 (54)	0.574
# 복순이 (61)	0.574
# 모든연기자들 (68)	0.574
# 연기자들 (4171)	0.572
# 이시영 (205)	0.571
# 효주누나 (163)	0.571
# 뭔놈 (93)	0.570
# 민하 (230)	0.570
# 림계진 (72)	0.569
# Hope (61)	0.569
# 나타샤 (88)	0.568
# 마동석아저씨 (60)	0.567
# 아놀드형 (60)	0.567
# first (53)	0.566
# 민효린 (133)	0.565
# 제이콥 (908)	0.565
# 진영 (836)	0.564
# 정우오빠 (94)	0.564
# 톰형 (519)	0.563
# 배우들 (79176)	0.562
# 옵대장 (67)	0.561
# 모건프리먼 (111)	0.560
# 윤시윤 (255)	0.560
# 김동완 (347)	0.558
# 레이첼맥아담스 (52)	0.558
# 밴 (92)	0.556
# 니암리슨 (54)	0.556
# 이선균씨 (191)	0.555
# 김동완씨 (56)	0.554
# 김보성 (1071)	0.552
# 동원님 (193)	0.552
# 경구 (69)	0.551
# 빵형 (61)	0.550
# 톰오빠 (51)	0.549
# 탐아저씨 (51)	0.549
# 송강호 (15617)	0.549
# 백두산 (62)	0.548
# 승룡 (73)	0.548
# 형래 (324)	0.546
# 지연 (1049)	0.546
# 탐형 (156)	0.545
# 유미 (70)	0.543
# 중기오빠 (166)	0.543
# 할리퀸 (5874)	0.542
# 빅뱅 (202)	0.542
# 혜교 (72)	0.542
# 복희 (63)	0.540
# 진세연 (308)	0.539
# 석현이 (229)	0.537
# 김환희 (54)	0.537
# 치아키 (436)	0.537
# 준기 (199)	0.535
# 데인드한 (198)	0.535
# 올라프 (771)	0.534
# 이준씨 (88)	0.534
# 정혜영 (103)	0.534
# 병헌 (178)	0.534
# 유노윤호 (60)	0.533
# 신성록 (60)	0.533
# 김성오 (90)	0.533
# 리암니슨 (1867)	0.533
# 정민이형 (92)	0.533
# 저우제룬 (62)	0.532
# 김상중 (115)	0.530
# 장생 (253)	0.530
# 이자스민 (51)	0.529
# 서영희 (51)	0.529
# 글라도스 (53)	0.529
# 노장 (123)	0.528
# 마요미 (250)	0.528
# 최승현 (566)	0.528
# 헐크 (3120)	0.526
# 봉감독 (1060)	0.525
# 리바인 (179)	0.525
# 김지운감독 (323)	0.523
# 한효주 (13802)	0.523
# 울라프 (207)	0.522
# 범수 (77)	0.519
# 짝대기 (52)	0.519
# 이현우 (164)	0.518
# 엄지원씨 (199)	0.518
# 이희준 (184)	0.516
# 유천 (62)	0.516
# 효주님 (64)	0.516
# 꼬마아이 (165)	0.515
# 동원이형 (66)	0.515
# 웨이웨이 (68)	0.515
# 헐크버스터 (142)	0.514
# 조지클루니 (150)	0.513
# 락다운 (76)	0.513
# 산악인들 (193)	0.513
# 사스 (209)	0.512
# 갓해진 (133)	0.511
# 믹키유천 (53)	0.509
# 장혁씨 (53)	0.509
# 명품조연들 (112)	0.509
# 김희원 (61)	0.508
# 이종석 (842)	0.507
# 홍매 (229)	0.507
# 김해숙 (308)	0.506
# 임수정 (392)	0.506
# 납뜩이 (355)	0.506
# 설리 (669)	0.505
# 강하늘 (107)	0.505
# 탑의 (545)	0.505
# 현서 (239)	0.504
# 송준기 (60)	0.500
# 마카오박 (187)	0.500
# 예진 (64)	0.500
# 남주들 (54)	0.500
# 스칼렛위치 (92)	0.500
# 박민하 (203)	0.500
# 전혜진 (60)	0.500
# 준기오빠 (120)	0.500
# 인챈트리스 (150)	0.500
# 테레사팔머 (57)	0.500
# 퀵실버 (1178)	0.500
# 그놈 (654)	0.498
# 71명 (161)	0.497
# 사나이들 (139)	0.496
# 정민 (137)	0.496
# 김수현 (2115)	0.496
# 조윤희 (437)	0.494
# 개장수 (85)	0.494
# 정재형 (83)	0.494
# 네빌 (81)	0.494
# 길라임 (67)	0.493
# 길리엄 (67)	0.493
# 이하늬씨 (65)	0.492
# 소피 (240)	0.492
# 김용화감독님 (57)	0.491
# 경슈 (55)	0.491
# 광대들 (108)	0.491
# 큐브릭 (53)	0.491
# 가오나시 (54)	0.491
# 가필드 (106)	0.491
# 원더우먼 (1442)	0.489
# 하와이피스톨 (138)	0.489
# 요한슨 (195)	0.487
# 김상경 (236)	0.487
# 김무열 (177)	0.486
# 민기 (106)	0.486
# 잘가다 (66)	0.485
# 공길 (358)	0.485
# 맥어보이 (157)	0.484
# 수안이 (182)	0.484
# 앤드류가필드 (60)	0.483

# %% [markdown]
# ## Named Entity Filter (Feature) 확인하기
#
# 우리는 window instance 를 하나의 row 로 만들었기 때문에 prediction probability 가 높은 instance 를 확인하면, 어떤 context 에서 X[0] 가 사람 이름인지를 확인할 수 있습니다.

# %%
train_prob = logistic.predict_proba(X_train)
top_instances = np.where(0.7 <= train_prob[:,1])[0]
top_probs = train_prob[top_instances,1]

print(top_instances.shape)
print(top_probs.shape)
# Out:
# (121960,)
# (121960,)

# %% [markdown]
# 121,960 개의 rows 중에는 중복된 것들도 많습니다. 중복된 경우를 정리하여 각 instance 와 count, 그리고 prediction probability 를 정리하는 함수를 만듭니다.

# %%
from collections import defaultdict

def get_unique_top_instances(X, sample_idxs, probs):

    # slice samples
    X_samples = X[sample_idxs]
    rows, cols = X_samples.nonzero()

    # find unique instance
    instance_prob = {}
    instance_count = defaultdict(int)
    before_row = None

    def update_dict(features, prob):
        features = sorted(features, key=lambda x:x[0])
        instance = ', '.join(f[1] for f in features)
        instance_prob[instance] = prob
        instance_count[instance] += 1
        return []

    features = [] # temporal variable
    for row, feature_idx in zip(rows, cols):
        # update unique dictionary
        if row != before_row and features:
            features = update_dict(features, probs[row])
        # update temporal variable
        before_row = row
        feature = idx_to_feature(feature_idx, idx_to_vocab, window=2)
        features.append((feature_idx, feature))

    # last elements
    if features:
        update_dict(features, probs[row])

    return instance_prob, instance_count

# %% [markdown]
# 여진히 unique instance (unique input vectors) 의 개수가 많습니다.

# %%
instance_prob, instance_count = get_unique_top_instances(X_train, top_instances, top_probs)
len(instance_prob)
# Out:
# 86816

# %% [markdown]
# 빈도수 기준으로 상위 500 개의 instance 를 출력합니다 (probability, count), instance 입니다.
#
# 영화평에서는 배우의 이름들이 반복하여 등장하는 경우들이 많습니다. 그러한 관용구들이 아래와 같은 템플릿으로 학습됩니다.
#
# ```
# (0.9405, 52)	X[-2] = 황정민, X[-1] = 과, X[1] = 의, X[2] = 케미
# (0.9751, 88)	X[-2] = 을, X[-1] = 위한, X[1] = 에, X[2] = 의한
# (0.8301, 45)	X[-2] = 솔직, X[-1] = 히, X[1] = 때문, X[2] = 에
# ```

# %%
sorted_instance_count = sorted(instance_count.items(), key=lambda x:-x[1])

for instance, count in sorted_instance_count[:500]:
    prob = instance_prob[instance]
    print('({:.4}, {})\t{}'.format(prob, count, instance))
# Out:
# (0.7002, 1344)	X[1] = 의, X[2] = 연기
# (0.9341, 1030)	X[1] = 때문, X[2] = 에
# (0.7056, 806)	X[1] = 의, X[2] = 연
# (0.9397, 598)	X[1] = 의, X[2] = 연기력
# (0.718, 548)	X[1] = 씨, X[2] = 연기
# (0.7298, 495)	X[-2] = 관람, X[-1] = 객, X[1] = 연, X[2] = 기가
# (0.8522, 490)	X[-2] = 관람, X[-1] = 객, X[1] = 의, X[2] = 연
# (0.8162, 423)	X[-2] = 관람, X[-1] = 객, X[1] = 의, X[2] = 연기
# (0.991, 358)	X[1] = 의, X[2] = 재
# (0.9865, 259)	X[-2] = 관람, X[-1] = 객, X[1] = 의, X[2] = 연기력
# (0.7456, 231)	X[1] = 을, X[2] = 위한
# (0.835, 218)	X[1] = 의, X[2] = 매력
# (0.9951, 196)	X[-2] = 관람, X[-1] = 객, X[1] = 연기, X[2] = 는
# (0.8036, 192)	X[-2] = 관람, X[-1] = 객, X[1] = 을, X[2] = 위한
# (0.7718, 188)	X[-2] = 관람, X[-1] = 객, X[1] = 때문, X[2] = 에
# (0.9054, 174)	X[-2] = 관람, X[-1] = 객, X[1] = 씨, X[2] = 연기
# (0.888, 173)	X[-2] = 에, X[-1] = 의한, X[1] = 을, X[2] = 위한
# (0.7207, 140)	X[-2] = 관람, X[-1] = 객, X[1] = 연기, X[2] = 너무
# (0.7982, 139)	X[1] = 씨, X[2] = 연
# (0.9267, 137)	X[-2] = 관람, X[-1] = 객, X[1] = 가, X[2] = 너무
# (0.7632, 129)	X[1] = 님, X[2] = 연기
# (0.8118, 122)	X[1] = 의, X[2] = 눈빛
# (0.8003, 117)	X[1] = 의, X[2] = 새로운
# (0.817, 112)	X[1] = 이란, X[2] = 배우
# (0.8274, 105)	X[1] = 씨의, X[2] = 연기
# (0.8325, 101)	X[-2] = 관람, X[-1] = 객, X[1] = 연기, X[2] = 진짜
# (0.8449, 98)	X[1] = 의, X[2] = 코믹
# (0.7698, 98)	X[-2] = 에, X[-1] = 의한, X[1] = 를, X[2] = 위한
# (0.8113, 97)	X[1] = 연기, X[2] = 짱
# (0.837, 97)	X[-2] = 관람, X[-1] = 객, X[1] = 연기, X[2] = 에
# (0.839, 93)	X[1] = 씨, X[2] = 너무
# (0.8003, 92)	X[-2] = 관람, X[-1] = 객, X[1] = 이, X[2] = 라는
# (0.9566, 92)	X[-2] = 재밌, X[-1] = 어요, X[1] = 짱
# (0.9346, 92)	X[-2] = 관람, X[-1] = 객, X[1] = 연기, X[2] = 정말
# (0.9751, 88)	X[-2] = 을, X[-1] = 위한, X[1] = 에, X[2] = 의한
# (0.8823, 88)	X[1] = 를, X[2] = 위한
# (0.875, 85)	X[-2] = 관람, X[-1] = 객, X[1] = 연기, X[2] = 최고
# (0.7387, 82)	X[-2] = 관람, X[-1] = 객, X[1] = 연기, X[2] = 짱
# (0.7118, 80)	X[1] = 짱짱, X[2] = 맨
# (0.961, 79)	X[1] = 의, X[2] = 카리스마
# (0.9699, 79)	X[1] = 와, X[2] = 박보영
# (0.9335, 75)	X[1] = 에, X[2] = 의한
# (0.7913, 75)	X[1] = 의, X[2] = 악역
# (0.9267, 72)	X[-2] = 송강호, X[-1] = 와, X[1] = 의, X[2] = 연기
# (0.7343, 72)	X[1] = 씨, X[2] = 정말
# (0.7632, 69)	X[1] = 씨의, X[2] = 연
# (0.9401, 69)	X[-2] = 타마코, X[-1] = 나의
# (0.8876, 68)	X[-2] = 관람, X[-1] = 객, X[1] = 의, X[2] = 매력
# (0.9823, 67)	X[1] = 이, X[2] = 살린
# (0.8201, 65)	X[1] = 가, X[2] = 연기
# (0.771, 65)	X[-2] = 관람, X[-1] = 객, X[1] = 씨, X[2] = 연
# (0.7432, 62)	X[-2] = 관람, X[-1] = 객, X[1] = 연, X[2] = 기도
# (0.7703, 60)	X[-2] = 관람, X[-1] = 객, X[1] = 의, X[2] = 재
# (0.9883, 59)	X[-2] = 관람, X[-1] = 객, X[1] = 은, X[2] = 역시
# (0.839, 56)	X[1] = 완전, X[2] = 멋있
# (0.827, 56)	X[1] = 의, X[2] = 원맨쇼
# (0.7137, 56)	X[-2] = 송강호, X[-1] = 와, X[1] = 의, X[2] = 연
# (0.9267, 55)	X[-2] = 관람, X[-1] = 객, X[1] = 연기, X[2] = 대박
# (0.797, 55)	X[1] = 씨, X[2] = 때문
# (0.8763, 55)	X[1] = 레저, X[2] = 의
# (0.9073, 55)	X[-2] = 관람, X[-1] = 객, X[1] = 과, X[2] = 송강호
# (0.766, 54)	X[1] = 연기, X[2] = 굿
# (0.8377, 53)	X[1] = 의, X[2] = 명품
# (0.922, 53)	X[-2] = 관람, X[-1] = 객, X[1] = 이, X[2] = 연기
# (0.8593, 53)	X[-2] = 관람, X[-1] = 객, X[1] = 의, X[2] = 코믹
# (0.7552, 52)	X[1] = 님의, X[2] = 연기
# (0.9405, 52)	X[-2] = 황정민, X[-1] = 과, X[1] = 의, X[2] = 케미
# (0.829, 51)	X[-2] = 관람, X[-1] = 객, X[1] = 이, X[2] = 살린
# (0.8062, 51)	X[-2] = 재밌, X[-1] = 었어요, X[1] = 짱
# (0.9611, 51)	X[-2] = 관람, X[-1] = 객, X[1] = 너무, X[2] = 멋
# (0.779, 50)	X[1] = 연기, X[2] = 소름
# (0.7482, 49)	X[1] = 의연, X[2] = 기가
# (0.9862, 49)	X[1] = 의, X[2] = 소름
# (0.7076, 49)	X[1] = 의, X[2] = 신들
# (0.9335, 48)	X[-2] = 강동원, X[-1] = 의, X[1] = 에, X[2] = 의한
# (0.901, 47)	X[1] = 씨, X[2] = 연기력
# (0.8581, 47)	X[-2] = 관람, X[-1] = 객, X[1] = 연기, X[2] = 잘
# (0.969, 47)	X[-2] = 관람, X[-1] = 객, X[1] = 님, X[2] = 연기
# (0.9032, 46)	X[1] = 을, X[2] = 다시보게
# (0.9054, 46)	X[1] = 연기, X[2] = 쩐다
# (0.8737, 46)	X[1] = 완전, X[2] = 멋
# (0.8019, 46)	X[1] = 씨, X[2] = 영화
# (0.8301, 45)	X[-2] = 솔직, X[-1] = 히, X[1] = 때문, X[2] = 에
# (0.9335, 45)	X[-2] = 관람, X[-1] = 객, X[1] = 에, X[2] = 의한
# (0.7944, 45)	X[-2] = 관람, X[-1] = 객, X[1] = 씨, X[2] = 너무
# (0.839, 45)	X[-2] = 관람, X[-1] = 객, X[1] = 멋있, X[2] = 다
# (0.7228, 45)	X[-2] = 황정민, X[-1] = 과, X[1] = 의, X[2] = 연
# (0.7616, 44)	X[1] = 과, X[2] = 오달수
# (0.9289, 44)	X[1] = 의, X[2] = 능청
# (0.9157, 43)	X[1] = 은, X[2] = 연기
# (0.8451, 43)	X[1] = 의, X[2] = 멋진
# (0.7306, 43)	X[-2] = 재미, X[-1] = 있어요, X[1] = 짱
# (0.733, 42)	X[1] = 이, X[2] = 살렸다
# (0.8359, 42)	X[-2] = 관람, X[-1] = 객, X[1] = 의, X[2] = 새로운
# (0.839, 42)	X[1] = 눈빛, X[2] = 연기
# (0.8623, 42)	X[-2] = 강동원, X[-1] = 과, X[1] = 의, X[2] = 케미
# (0.7293, 41)	X[1] = 연기짱
# (0.9259, 41)	X[-2] = 관람, X[-1] = 객, X[1] = 짱짱, X[2] = 맨
# (0.9063, 41)	X[-2] = 관람, X[-1] = 객, X[1] = 의, X[2] = 액션
# (0.7613, 41)	X[1] = 의, X[2] = 명연
# (0.9011, 40)	X[1] = 의, X[2] = 인생
# (0.8564, 40)	X[1] = 팬이, X[2] = 라
# (0.9247, 40)	X[1] = 랑, X[2] = 박보영
# (0.7318, 39)	X[-2] = 연기, X[-1] = 와, X[1] = 의, X[2] = 연기
# (0.9708, 39)	X[1] = 의, X[2] = 발견
# (0.8876, 39)	X[1] = 의, X[2] = 미친
# (0.9267, 38)	X[-2] = 관람, X[-1] = 객, X[1] = 의연, X[2] = 기가
# (0.839, 38)	X[-2] = 황정민, X[-1] = 과, X[1] = 의, X[2] = 연기
# (0.8136, 37)	X[-2] = 그래, X[-1] = 도, X[1] = 의, X[2] = 연기
# (0.8171, 37)	X[-2] = 관람, X[-1] = 객, X[1] = 씨의, X[2] = 연
# (0.9432, 37)	X[-2] = 관람, X[-1] = 객, X[1] = 의, X[2] = 인생
# (0.9278, 37)	X[-2] = 관람, X[-1] = 객, X[1] = 연, X[2] = 기대
# (0.9915, 37)	X[-2] = 황정민, X[-1] = 과, X[1] = 의, X[2] = 연기력
# (0.9481, 36)	X[-2] = 관람, X[-1] = 객, X[1] = 이, X[2] = 주인공
# (0.7795, 35)	X[-2] = 관람, X[-1] = 객, X[1] = 의, X[2] = 능청
# (0.7647, 35)	X[-2] = 송강호, X[-1] = 와, X[1] = 의, X[2] = 연기력
# (0.9904, 34)	X[1] = 가, X[2] = 범인
# (0.8414, 34)	X[-2] = 강동원, X[-1] = 과, X[1] = 의, X[2] = 연
# (0.9764, 34)	X[-2] = 관람, X[-1] = 객, X[1] = 랑, X[2] = 할리퀸
# (0.7859, 33)	X[1] = 나, X[2] = 온다고
# (0.8304, 33)	X[-2] = 를, X[-1] = 위한, X[1] = 에, X[2] = 의한
# (0.8245, 33)	X[-2] = 관람, X[-1] = 객, X[1] = 연기, X[2] = 넘
# (0.739, 33)	X[-2] = 관람, X[-1] = 객, X[1] = 연기, X[2] = 굿
# (0.991, 33)	X[-2] = 관람, X[-1] = 객, X[1] = 연기, X[2] = 소름
# (0.9284, 33)	X[1] = 악역, X[2] = 연기
# (0.7657, 33)	X[-2] = 관람, X[-1] = 객, X[1] = 와, X[2] = 할리퀸
# (0.8632, 32)	X[1] = 의, X[2] = 표정
# (0.7411, 32)	X[-2] = 그래, X[-1] = 도, X[1] = 때문, X[2] = 에
# (0.9967, 32)	X[1] = 이, X[2] = 멋있
# (0.7768, 32)	X[1] = 팬이, X[2] = 라서
# (0.9317, 32)	X[-2] = 하정우, X[-1] = 의, X[1] = 에, X[2] = 의한
# (0.8841, 32)	X[-2] = 하정우, X[-1] = 와, X[1] = 의, X[2] = 케미
# (0.8759, 32)	X[-2] = 관람, X[-1] = 객, X[1] = 너무, X[2] = 멋있
# (0.7795, 31)	X[1] = 넘, X[2] = 멋
# (0.9694, 31)	X[1] = 씨의, X[2] = 연기력
# (0.945, 31)	X[-2] = 하정우, X[-1] = 와, X[1] = 의, X[2] = 연기
# (0.998, 31)	X[1] = 랑, X[2] = 한효주
# (0.7674, 30)	X[1] = 연기, X[2] = 쩔어
# (0.9435, 30)	X[1] = 의, X[2] = 포스
# (0.911, 30)	X[-2] = 있, X[-1] = 었어요, X[1] = 짱
# (0.8855, 30)	X[-2] = 관람, X[-1] = 객, X[1] = 의
# (0.9851, 30)	X[-2] = 관람, X[-1] = 객, X[1] = 를, X[2] = 위한
# (0.8242, 30)	X[-1] = 역시, X[1] = 의, X[2] = 연기
# (0.8185, 30)	X[1] = 형님, X[2] = 이
# (0.7174, 29)	X[1] = 짱짱, X[2] = 짱
# (0.9376, 29)	X[-2] = 관람, X[-1] = 객, X[1] = 이란, X[2] = 배우
# (0.7655, 29)	X[-2] = 관람, X[-1] = 객, X[1] = 씨의, X[2] = 연기
# (0.7484, 29)	X[-2] = 무엇, X[-1] = 보다, X[1] = 의, X[2] = 연
# (0.7632, 29)	X[-2] = 관람, X[-1] = 객, X[1] = 잘, X[2] = 생겼어요
# (0.7357, 29)	X[1] = 과, X[2] = 도경수
# (0.7874, 29)	X[-2] = 관람, X[-1] = 객, X[1] = 와, X[2] = 송강호
# (0.9945, 29)	X[-2] = 관람, X[-1] = 객, X[1] = 송강호, X[2] = 연기
# (0.8973, 29)	X[1] = 랑, X[2] = 할리퀸
# (0.7508, 28)	X[1] = 님, X[2] = 정말
# (0.839, 28)	X[1] = 님, X[2] = 연
# (0.7238, 28)	X[1] = 가, X[2] = 주연
# (0.8231, 28)	X[1] = 연기, X[2] = 빼고
# (0.7613, 28)	X[1] = 의, X[2] = 사랑
# (0.9346, 28)	X[1] = 씨, X[2] = 팬이
# (0.7961, 28)	X[1] = 의, X[2] = 색다
# (0.7086, 28)	X[1] = 님, X[2] = 때문
# (0.7944, 28)	X[1] = 와, X[2] = 한효주
# (0.8446, 27)	X[1] = 의재, X[2] = 발견
# (0.792, 27)	X[1] = 형님, X[2] = 의
# (0.8541, 27)	X[1] = 얼굴, X[2] = 만
# (0.7419, 27)	X[1] = 짱, X[2] = ㅋㅋㅋ
# (0.7969, 27)	X[1] = 의, X[2] = 맛깔
# (0.7925, 27)	X[1] = 씨, X[2] = 진짜
# (0.8723, 27)	X[-2] = 관람, X[-1] = 객, X[1] = 연기, X[2] = 역시
# (0.7301, 27)	X[-2] = 관람, X[-1] = 객, X[1] = 은, X[2] = 정말
# (0.8759, 27)	X[-2] = 관람, X[-1] = 객, X[1] = 의, X[2] = 멋진
# (0.7613, 27)	X[-1] = 역시, X[1] = 이, X[2] = 라는
# (0.7431, 27)	X[-2] = 관람, X[-1] = 객, X[1] = 라는, X[2] = 배우
# (0.8055, 27)	X[1] = 박보영, X[2] = 연기
# (0.9167, 27)	X[-2] = 관람, X[-1] = 객, X[1] = 보러갔다, X[2] = 가
# (0.7933, 27)	X[-2] = 강동원, X[-1] = 과, X[1] = 의, X[2] = 연기
# (0.923, 26)	X[1] = 가, X[2] = 살린
# (0.8202, 26)	X[1] = 같은, X[2] = 대통령
# (0.7271, 26)	X[1] = 와, X[2] = 할리퀸
# (0.918, 25)	X[-2] = 하정우, X[-1] = 와, X[1] = 의, X[2] = 연
# (0.8927, 25)	X[1] = 의, X[2] = 또다른
# (0.9149, 25)	X[-2] = 관람, X[-1] = 객, X[1] = 씨의, X[2] = 연기력
# (0.8128, 25)	X[1] = 은, X[2] = 멋
# (0.8326, 25)	X[1] = 의, X[2] = 죽음
# (0.7982, 25)	X[-2] = 관람, X[-1] = 객, X[1] = 와, X[2] = 오달수
# (0.819, 25)	X[1] = 과, X[2] = 이나영
# (0.7354, 24)	X[-2] = 김윤석, X[-1] = 과, X[1] = 의, X[2] = 연기
# (0.8748, 24)	X[1] = 씨, X[2] = 나오는
# (0.7549, 24)	X[1] = 님, X[2] = 너무
# (0.8348, 24)	X[1] = 의, X[2] = 최고
# (0.722, 24)	X[-2] = 재밌, X[-1] = 어요, X[1] = 씨, X[2] = 연기
# (0.7312, 24)	X[-2] = 관람, X[-1] = 객, X[1] = 만, X[2] = 보이는
# (0.891, 24)	X[-2] = 객, X[-1] = 역시, X[1] = 의, X[2] = 연기
# (0.7793, 24)	X[-2] = 관람, X[-1] = 객, X[1] = 짱, X[2] = 너무
# (0.7029, 24)	X[1] = 의, X[2] = 얼굴
# (0.965, 24)	X[-2] = 관람, X[-1] = 객, X[1] = 의, X[2] = 강동원
# (0.9077, 23)	X[-2] = 재밌, X[-1] = 어요, X[1] = 연, X[2] = 기가
# (0.7392, 23)	X[-2] = 게, X[-1] = 봤어요, X[1] = 짱
# (0.8836, 23)	X[-2] = 무엇, X[-1] = 보다, X[1] = 의, X[2] = 연기
# (0.7295, 23)	X[1] = 씨가, X[2] = 연기
# (0.7814, 23)	X[1] = 짱, X[2] = 진짜
# (0.9273, 23)	X[-2] = 관람, X[-1] = 객, X[1] = 의, X[2] = 원맨쇼
# (0.9011, 23)	X[-2] = 관람, X[-1] = 객, X[1] = 연기, X[2] = 짱짱
# (0.8485, 23)	X[-2] = 관람, X[-1] = 객, X[1] = 의, X[2] = 악역
# (0.7944, 22)	X[-2] = 관람, X[-1] = 객, X[1] = 너무, X[2] = 좋아
# (0.9336, 22)	X[1] = 가, X[2] = 나와서
# (0.9314, 22)	X[1] = 연기, X[2] = 역시
# (0.9724, 22)	X[1] = 이, X[2] = 진리
# (0.9453, 22)	X[1] = 완전, X[2] = 멋있음
# (0.9622, 22)	X[1] = 의, X[2] = 배우
# (0.88, 22)	X[-2] = 잘, X[-1] = 봤습니다, X[1] = 짱
# (0.7577, 22)	X[1] = 의, X[2] = 내면
# (0.8636, 22)	X[-2] = 관람, X[-1] = 객, X[1] = 와, X[2] = 강아지
# (0.7541, 22)	X[-2] = 관람, X[-1] = 객, X[1] = 이, X[2] = 멋있
# (0.7397, 22)	X[-2] = 는, X[-1] = 왕이고싶었고, X[1] = 은, X[2] = 사람
# (0.805, 21)	X[1] = 을, X[2] = 비롯
# (0.7829, 21)	X[1] = 땜에, X[2] = 봤
# (0.8691, 21)	X[-2] = 관람, X[-1] = 객, X[1] = 짱짱, X[2] = 짱
# (0.9471, 21)	X[-2] = 관람, X[-1] = 객, X[1] = 얼굴, X[2] = 이
# (0.7969, 21)	X[1] = 의, X[2] = 목소리
# (0.8478, 21)	X[-2] = 관람, X[-1] = 객, X[1] = 가, X[2] = 연기
# (0.9797, 21)	X[-2] = 관람, X[-1] = 객, X[1] = 사랑, X[2] = 해요
# (0.8729, 21)	X[-2] = 이정재, X[-1] = 와, X[1] = 의, X[2] = 연
# (0.865, 21)	X[1] = 의, X[2] = 기럭지
# (0.9203, 20)	X[1] = 의, X[2] = 첫
# (0.8061, 20)	X[-1] = 역시, X[1] = 연기, X[2] = 는
# (0.9944, 20)	X[1] = 연기, X[2] = 짱짱
# (0.7303, 20)	X[1] = 진짜, X[2] = 멋있음
# (0.7161, 20)	X[1] = 가, X[2] = 진리
# (0.8062, 20)	X[1] = 완전, X[2] = 멋짐
# (0.8279, 20)	X[-2] = 관람, X[-1] = 객, X[1] = 짱
# (0.8231, 20)	X[-2] = 관람, X[-1] = 객, X[1] = 얼굴, X[2] = 만
# (0.8216, 20)	X[-2] = 관람, X[-1] = 객, X[1] = 이, X[2] = 진짜
# (0.9422, 20)	X[-2] = 관람, X[-1] = 객, X[1] = 연기, X[2] = 완전
# (0.9885, 20)	X[1] = 님의, X[2] = 연
# (0.8165, 20)	X[1] = 때문, X[2] = 에봤
# (0.7363, 20)	X[1] = 연기, X[2] = 쵝오
# (0.9346, 20)	X[-2] = 관람, X[-1] = 객, X[1] = 역시, X[2] = 연기
# (0.8007, 20)	X[-2] = 강동원, X[-1] = 과, X[1] = 의, X[2] = 조합
# (0.7454, 20)	X[-2] = 객, X[-1] = 역시, X[1] = 배우, X[2] = 황정민
# (0.7859, 20)	X[1] = 과, X[2] = 조진웅
# (0.7753, 19)	X[-2] = 그러, X[-1] = 나, X[1] = 의, X[2] = 연기
# (0.9509, 19)	X[1] = 씨, X[2] = 기대
# (0.8231, 19)	X[1] = 연기, X[2] = 굳
# (0.9287, 19)	X[1] = 가, X[2] = 멋있
# (0.9306, 19)	X[1] = 의, X[2] = 절제
# (0.9587, 19)	X[1] = 의, X[2] = 외모
# (0.7718, 19)	X[-2] = 관람, X[-1] = 객, X[1] = 이, X[2] = 이렇게
# (0.864, 19)	X[-2] = 관람, X[-1] = 객, X[1] = 연기력, X[2] = 에
# (0.8611, 19)	X[-2] = 관람, X[-1] = 객, X[1] = 연기력, X[2] = 짱
# (0.8673, 19)	X[-2] = 관람, X[-1] = 객, X[1] = 연기, X[2] = 잘함
# (0.9149, 19)	X[-2] = 관람, X[-1] = 객, X[1] = 완전, X[2] = 멋
# (0.7839, 19)	X[-2] = 영화, X[-1] = 다, X[1] = 의, X[2] = 연기
# (0.8815, 19)	X[1] = 오빠, X[2] = 너무
# (0.7759, 19)	X[-2] = 재밌, X[-1] = 어요, X[1] = 연, X[2] = 기도
# (0.965, 19)	X[-2] = 연기력, X[-1] = 과, X[1] = 의, X[2] = 연기력
# (0.8949, 19)	X[-2] = 관람, X[-1] = 객, X[1] = 과, X[2] = 정우
# (0.7992, 19)	X[1] = 과, X[2] = 한석규
# (0.7955, 18)	X[1] = 내꺼
# (0.864, 18)	X[-1] = 배우, X[1] = 의, X[2] = 재
# (0.8626, 18)	X[1] = 너무, X[2] = 멋있음
# (0.8167, 18)	X[1] = 한테, X[2] = 반
# (0.9663, 18)	X[1] = 씨, X[2] = 역시
# (0.7316, 18)	X[1] = 의, X[2] = 힘
# (0.8748, 18)	X[-2] = 관람, X[-1] = 객, X[1] = 연기, X[2] = 짱이
# (0.9294, 18)	X[-2] = 관람, X[-1] = 객, X[1] = 의, X[2] = 명품
# (0.7079, 18)	X[-2] = 관람, X[-1] = 객, X[1] = 인생, X[2] = 연기
# (0.8392, 18)	X[1] = 오빠, X[2] = 의
# (0.775, 18)	X[-2] = 객, X[-1] = 역시, X[1] = 배우, X[2] = 하정우
# (0.9257, 18)	X[1] = 넘, X[2] = 멋있
# (0.7964, 18)	X[-2] = 관람, X[-1] = 객, X[1] = 연기, X[2] = 좋아
# (0.8259, 18)	X[-2] = 관람, X[-1] = 객, X[1] = 진짜, X[2] = 멋
# (0.8009, 18)	X[-2] = 관람, X[-1] = 객, X[1] = 악역, X[2] = 연기
# (0.9873, 18)	X[-2] = 강동원, X[-1] = 과, X[1] = 의, X[2] = 연기력
# (0.7401, 17)	X[-2] = 관람, X[-1] = 객, X[1] = 연기, X[2] = 쩔어
# (0.8177, 17)	X[1] = 를위, X[2] = 한
# (0.7688, 17)	X[1] = 를, X[2] = 다시보게
# (0.8685, 17)	X[1] = 넘, X[2] = 멋져
# (0.7333, 17)	X[1] = 짱, X[2] = ㅠㅠ
# (0.804, 17)	X[-2] = ㅋㅋㅋ, X[-1] = ㅋ, X[1] = 짱
# (0.7073, 17)	X[1] = 밖에, X[2] = 안보
# (0.9378, 17)	X[-2] = 게, X[-1] = 봤어요, X[1] = 씨, X[2] = 연기
# (0.956, 17)	X[-2] = 재밌, X[-1] = 었어요, X[1] = 씨, X[2] = 연기
# (0.7568, 17)	X[-2] = 관람, X[-1] = 객, X[1] = 님, X[2] = 연
# (0.7944, 17)	X[-2] = 관람, X[-1] = 객, X[1] = 님의, X[2] = 연
# (0.9049, 17)	X[-2] = 객, X[-1] = 역시, X[1] = 연기, X[2] = 는
# (0.9156, 17)	X[-2] = 관람, X[-1] = 객, X[1] = 는, X[2] = 사랑
# (0.9843, 17)	X[-2] = 한, X[-1] = 영화, X[1] = 의, X[2] = 연기
# (0.8054, 17)	X[-2] = 관람, X[-1] = 객, X[1] = 씨, X[2] = 정말
# (0.9185, 17)	X[-2] = 객, X[-1] = 역시, X[1] = 믿고, X[2] = 보는
# (0.9871, 17)	X[-2] = 관람, X[-1] = 객, X[1] = 은, X[2] = 사랑
# (0.9488, 17)	X[-2] = 재밌, X[-1] = 다, X[1] = 짱
# (0.7543, 17)	X[-2] = 관람, X[-1] = 객, X[1] = 의, X[2] = 미친
# (0.7498, 17)	X[1] = 의, X[2] = 광기
# (0.7383, 17)	X[-2] = 박보영, X[-1] = 과, X[1] = 의, X[2] = 연
# (0.7585, 17)	X[-2] = 관람, X[-1] = 객, X[1] = 가, X[2] = 정말
# (0.9828, 17)	X[1] = 진짜, X[2] = 멋있고
# (0.7031, 17)	X[-2] = 관람, X[-1] = 객, X[1] = 넘, X[2] = 멋
# (0.945, 17)	X[-2] = 관람, X[-1] = 객, X[1] = 와, X[2] = 전지현
# (0.7505, 17)	X[-2] = 관람, X[-1] = 객, X[1] = 을, X[2] = 다시보게
# (0.8275, 17)	X[-2] = 박보영, X[-1] = 과, X[1] = 의, X[2] = 연기력
# (0.7646, 16)	X[-2] = 관람, X[-1] = 객, X[1] = 너무, X[2] = 이뻐
# (0.7135, 16)	X[1] = 의, X[2] = 활약
# (0.9864, 16)	X[-1] = 역시, X[1] = 라는, X[2] = 말이
# (0.8781, 16)	X[1] = 씨, X[2] = 완전
# (0.924, 16)	X[1] = 씨, X[2] = 넘
# (0.7201, 16)	X[-2] = 본, X[-1] = 영화, X[1] = 의, X[2] = 연기
# (0.9549, 16)	X[-2] = 되는, X[-1] = 영화, X[1] = 씨, X[2] = 연기
# (0.8677, 16)	X[1] = 씨, X[2] = 믿고
# (0.987, 16)	X[1] = 씨, X[2] = 덕분에
# (0.7188, 16)	X[-2] = 관람, X[-1] = 객, X[1] = 님, X[2] = 너무
# (0.9267, 16)	X[-2] = 관람, X[-1] = 객, X[1] = 연, X[2] = 기만
# (0.7495, 16)	X[-2] = 관람, X[-1] = 객, X[1] = 보러, X[2] = 갔다
# (0.7182, 16)	X[-2] = 관람, X[-1] = 객, X[1] = 이, X[2] = 나오는
# (0.8111, 16)	X[1] = 의, X[2] = 팬이
# (0.9885, 16)	X[1] = 의, X[2] = 광
# (0.7148, 16)	X[-2] = 스토리, X[-1] = 와, X[1] = 의, X[2] = 연기
# (0.7444, 16)	X[-2] = 관람, X[-1] = 객, X[1] = 배두나, X[2] = 오달수
# (0.9217, 16)	X[-2] = 관람, X[-1] = 객, X[1] = 도, X[2] = 멋있고
# (0.7011, 16)	X[1] = 은, X[2] = 멋있고
# (0.7989, 16)	X[-2] = 강동원, X[-1] = 과, X[1] = 의, X[2] = 캐미
# (0.7105, 16)	X[-2] = 관람, X[-1] = 객, X[1] = 짱, X[2] = 황정민
# (0.9407, 16)	X[-2] = 관람, X[-1] = 객, X[1] = 이랑, X[2] = 황정민
# (0.8118, 16)	X[1] = 과, X[2] = 정진영
# (0.9438, 16)	X[-2] = 관람, X[-1] = 객, X[1] = 송강호, X[2] = 연
# (0.8104, 15)	X[-1] = 역시, X[1] = 의, X[2] = 연기력
# (0.9017, 15)	X[-2] = 김윤석, X[-1] = 과, X[1] = 의, X[2] = 연기력
# (0.9808, 15)	X[1] = 완전, X[2] = 멋져
# (0.8053, 15)	X[1] = 는, X[2] = 멋
# (0.8155, 15)	X[1] = 완전, X[2] = 멋있고
# (0.7591, 15)	X[1] = 이, X[2] = 하드캐리
# (0.7564, 15)	X[-2] = 관람, X[-1] = 객, X[1] = 의, X[2] = 또다른
# (0.7517, 15)	X[1] = 은, X[2] = 멋있
# (0.8668, 15)	X[-2] = 관람, X[-1] = 객, X[1] = 너무, X[2] = 멋져요
# (0.839, 15)	X[1] = 의, X[2] = 대사
# (0.9952, 15)	X[1] = 박보영, X[2] = 왕석현
# (0.8833, 15)	X[1] = 짱, X[2] = 멋있
# (0.9236, 15)	X[1] = 와, X[2] = 오달수
# (0.7089, 15)	X[1] = 이, X[2] = 멋
# (0.8262, 15)	X[-2] = 관람, X[-1] = 객, X[1] = 진짜, X[2] = 멋있
# (0.8673, 15)	X[1] = 과, X[2] = 송혜교
# (0.9986, 15)	X[-1] = 니콜라스, X[1] = 때문, X[2] = 에
# (0.9945, 15)	X[-1] = 니콜라스, X[1] = 의, X[2] = 매력
# (0.9888, 14)	X[1] = 의, X[2] = 새로운모습
# (0.761, 14)	X[-1] = 그나마, X[1] = 때문, X[2] = 에
# (0.8234, 14)	X[1] = 의, X[2] = OOO
# (0.7563, 14)	X[1] = 짱, X[2] = 너무
# (0.7267, 14)	X[1] = 만, X[2] = 불쌍
# (0.8108, 14)	X[1] = 짱, X[2] = 멋짐
# (0.7126, 14)	X[1] = 씨, X[2] = 최고
# (0.9503, 14)	X[1] = 의, X[2] = 발
# (0.9616, 14)	X[-2] = 에, X[-1] = 의한, X[1] = 를위, X[2] = 한
# (0.8756, 14)	X[1] = 오빠, X[2] = 짱
# (0.8469, 14)	X[1] = 는, X[2] = 멋있
# (0.9869, 14)	X[1] = 연기, X[2] = ㄷㄷ
# (0.8773, 14)	X[-2] = 잘, X[-1] = 봤습니다, X[1] = 씨, X[2] = 연기
# (0.7217, 14)	X[1] = 가, X[2] = 불쌍
# (0.8323, 14)	X[-2] = 게, X[-1] = 봤습니다, X[1] = 씨, X[2] = 연기
# (0.7196, 14)	X[-2] = 관람, X[-1] = 객, X[1] = 특유, X[2] = 의
# (0.7567, 14)	X[1] = 의, X[2] = 존재감이
# (0.7116, 14)	X[-2] = 관람, X[-1] = 객, X[1] = 가, X[2] = 멋
# (0.9327, 14)	X[-2] = 관람, X[-1] = 객, X[1] = 정말, X[2] = 멋
# (0.8628, 14)	X[1] = 짱, X[2] = ㅋㅋ
# (0.9813, 14)	X[-2] = 손예진, X[-1] = 과, X[1] = 의, X[2] = 연
# (0.9935, 14)	X[-2] = 관람, X[-1] = 객, X[1] = 의, X[2] = 마지막
# (0.942, 14)	X[-2] = 관람, X[-1] = 객, X[1] = 연기력, X[2] = 최고
# (0.9818, 14)	X[-1] = 배우, X[1] = 의, X[2] = 연기
# (0.9857, 14)	X[-1] = 히스, X[1] = 의, X[2] = 연기
# (0.9316, 14)	X[-2] = 재밌, X[-1] = 어요, X[1] = 연기, X[2] = 너무
# (0.82, 14)	X[1] = 과, X[2] = 곽도원
# (0.8112, 14)	X[1] = 오빠, X[2] = 가
# (0.8406, 14)	X[1] = 가, X[2] = 초
# (0.9263, 14)	X[-2] = 관람, X[-1] = 객, X[1] = 가, X[2] = 멋있
# (0.8468, 14)	X[-2] = 관람, X[-1] = 객, X[1] = 짱, X[2] = 강동원
# (0.7717, 14)	X[-1] = 황정민, X[1] = 이성민, X[2] = 박성웅
# (0.7187, 14)	X[-2] = 관람, X[-1] = 객, X[1] = 의, X[2] = 소름
# (0.858, 14)	X[-2] = 박해일, X[-1] = 과, X[1] = 의, X[2] = 연기
# (0.8741, 14)	X[1] = 박보영, X[2] = 둘다
# (0.9157, 13)	X[1] = 땜에, X[2] = 1점
# (0.8783, 13)	X[1] = 연기, X[2] = 빼곤
# (0.9659, 13)	X[-1] = 배우, X[1] = 의, X[2] = 연기력
# (0.9729, 13)	X[1] = 연기, X[2] = 좋다
# (0.8076, 13)	X[1] = 얼굴, X[2] = 에
# (0.9, 13)	X[1] = 의, X[2] = 다른
# (0.813, 13)	X[1] = 연기굿
# (0.9335, 13)	X[-2] = 전지현, X[-1] = 의, X[1] = 에, X[2] = 의한
# (0.9662, 13)	X[1] = 씨, X[2] = 매력
# (0.8043, 13)	X[-2] = 있는, X[-1] = 영화, X[1] = 의, X[2] = 연기
# (0.9233, 13)	X[1] = 씨
# (0.9478, 13)	X[1] = 씨의, X[2] = 코믹
# (0.972, 13)	X[1] = 씨가, X[2] = 너무
# (0.8435, 13)	X[-2] = 객, X[-1] = 역시, X[1] = 이, X[2] = 라는
# (0.7355, 13)	X[-2] = 영화, X[-1] = 였다, X[1] = 의, X[2] = 연
# (0.7309, 13)	X[-2] = 관람, X[-1] = 객, X[1] = 연기, X[2] = 좋네요
# (0.7259, 13)	X[-2] = 영화, X[-1] = 였습니다, X[1] = 씨, X[2] = 연기
# (0.7776, 13)	X[-2] = 관람, X[-1] = 객, X[1] = 역시, X[2] = 믿고
# (0.7135, 13)	X[-2] = 재밌, X[-1] = 어요, X[1] = 짱짱
# (0.9828, 13)	X[-2] = 관람, X[-1] = 객, X[1] = 님의, X[2] = 연기
# (0.823, 13)	X[-2] = 관람, X[-1] = 객, X[1] = 형님, X[2] = 의
# (0.7075, 13)	X[1] = 의, X[2] = 능글
# (0.7135, 13)	X[1] = 의, X[2] = 신들린연기
# (0.7172, 13)	X[1] = 의, X[2] = 간지
# (0.724, 13)	X[1] = 의, X[2] = 미소
# (0.8345, 13)	X[1] = 짱, X[2] = 완전
# (0.7118, 13)	X[-2] = 관람, X[-1] = 객, X[1] = 의, X[2] = 하정우
# (0.8583, 13)	X[-2] = 관람, X[-1] = 객, X[1] = 연기, X[2] = 잘하
# (0.821, 13)	X[1] = 오달수, X[2] = 연기
# (0.8359, 13)	X[-2] = 관람, X[-1] = 객, X[1] = 도, X[2] = 멋
# (0.9302, 13)	X[-2] = 관람, X[-1] = 객, X[1] = 멋, X[2] = 지다
# (0.9917, 13)	X[-2] = 황정민, X[-1] = 과, X[1] = 의, X[2] = 조합
# (0.7711, 13)	X[-2] = 스토리, X[-1] = 와, X[1] = 의, X[2] = 연기력
# (0.9957, 13)	X[-2] = 관람, X[-1] = 객, X[1] = 너무, X[2] = 멋있고
# (0.839, 13)	X[1] = 연기, X[2] = 짱이
# (0.7045, 13)	X[-1] = 송강호, X[1] = 의, X[2] = 연기
# (0.7002, 13)	X[-2] = 관람, X[-1] = 객, X[1] = 너무, X[2] = 잘생김
# (0.7898, 13)	X[-2] = 김명민, X[-1] = 과, X[1] = 의, X[2] = 연기
# (0.8391, 13)	X[-2] = 관람, X[-1] = 객, X[1] = 의, X[2] = 좀비
# (0.8227, 13)	X[-2] = 관람, X[-1] = 객, X[1] = 와, X[2] = 마동석
# (0.9569, 12)	X[1] = 의, X[2] = OOO기력
# (0.7406, 12)	X[1] = 이, X[2] = 나오니
# (0.8091, 12)	X[-2] = 관람, X[-1] = 객, X[1] = 의, X[2] = 카리스마
# (0.9483, 12)	X[1] = 가, X[2] = 죽어서
# (0.8206, 12)	X[1] = 의, X[2] = 사투리
# (0.9571, 12)	X[1] = 언니, X[2] = 연기
# (0.8179, 12)	X[1] = 만, X[2] = 멋
# (0.7883, 12)	X[1] = 오빠, X[2] = 사랑
# (0.8756, 12)	X[1] = 짱, X[2] = 멋
# (0.9195, 12)	X[1] = 오빠, X[2] = 연기
# (0.9912, 12)	X[1] = 씨, X[2] = 짱
# (0.8867, 12)	X[1] = 가, X[2] = 나왔으면
# (0.8253, 12)	X[-2] = 영화, X[-1] = 특히, X[1] = 의, X[2] = 연기
# (0.9798, 12)	X[-2] = 재밌, X[-1] = 어요, X[1] = 도, X[2] = 멋있고
# (0.794, 12)	X[1] = 의, X[2] = 진가
# (0.8122, 12)	X[1] = 씨의, X[2] = 매력
# (0.8789, 12)	X[-2] = 관람, X[-1] = 객, X[1] = 씨, X[2] = 때문
# (0.964, 12)	X[-2] = 관람, X[-1] = 객, X[1] = 씨, X[2] = 연기력
# (0.9757, 12)	X[-2] = 관람, X[-1] = 객, X[1] = 씨, X[2] = 영화
# (0.945, 12)	X[-2] = 관람, X[-1] = 객, X[1] = 밖에, X[2] = 안
# (0.8623, 12)	X[1] = 이, X[2] = 잘생겨
# (0.9065, 12)	X[-2] = 객, X[-1] = 역시, X[1] = 나오는, X[2] = 영화
# (0.7097, 12)	X[-2] = 관람, X[-1] = 객, X[1] = 이, X[2] = 돋보
# (0.7632, 12)	X[-1] = 역시, X[1] = 믿고, X[2] = 보는
# (0.8624, 12)	X[-2] = 관람, X[-1] = 객, X[1] = 배우, X[2] = 님의
# (0.941, 12)	X[-2] = 관람, X[-1] = 객, X[1] = 연기, X[2] = 의
# (0.9523, 12)	X[-2] = 관람, X[-1] = 객, X[1] = 너무, X[2] = 연기
# (0.7855, 12)	X[1] = 의, X[2] = 빈자리
# (0.8101, 12)	X[1] = 의, X[2] = 비중이
# (0.7175, 12)	X[1] = 밖에, X[2] = 기억
# (0.724, 12)	X[1] = 의, X[2] = 존재감
# (0.7648, 12)	X[-2] = 관람, X[-1] = 객, X[1] = 와, X[2] = 김태리
# (0.8654, 12)	X[-2] = 관람, X[-1] = 객, X[1] = 너무, X[2] = 예뻐
# (0.8588, 12)	X[1] = 와, X[2] = 김태리
# (0.7517, 12)	X[1] = 개, X[2] = 멋있음
# (0.8752, 12)	X[1] = 가, X[2] = 아니었다면
# (0.9037, 12)	X[1] = 의, X[2] = 캐스팅
# (0.9872, 12)	X[-2] = 박보영, X[-1] = 과, X[1] = 의, X[2] = 연기
# (0.9312, 12)	X[1] = 배두나, X[2] = 오달수
# (0.9296, 12)	X[-2] = 를위, X[-1] = 한, X[1] = 에, X[2] = 의한
# (0.8004, 12)	X[-2] = 관람, X[-1] = 객, X[1] = 연기잘, X[2] = 한다
# (0.7902, 12)	X[-2] = 객, X[-1] = 역시, X[1] = 믿고, X[2] = 봅니다
# (0.9094, 12)	X[-2] = 관람, X[-1] = 객, X[1] = 가, X[2] = 잘
# (0.8134, 12)	X[1] = 오달수, X[2] = 콤비
# (0.7928, 12)	X[-2] = 최민식, X[-1] = 과, X[1] = 의, X[2] = 연기
# (0.9737, 12)	X[-2] = 관람, X[-1] = 객, X[1] = 은, X[2] = 그냥
# (0.9916, 12)	X[-2] = 최민식, X[-1] = 과, X[1] = 의, X[2] = 연
# (0.972, 12)	X[-2] = 화가, X[-1] = 될듯, X[1] = 씨, X[2] = 포스
# (0.8513, 12)	X[-2] = 강동원, X[-1] = 이랑, X[1] = 때문, X[2] = 에
# (0.8673, 12)	X[-2] = 관람, X[-1] = 객, X[1] = 은, X[2] = 잘생겼다
# (0.8009, 12)	X[1] = 은, X[2] = 잘생겼다
# (0.8623, 12)	X[-2] = 관람, X[-1] = 객, X[1] = 은, X[2] = 멋
# (0.8335, 12)	X[1] = 의, X[2] = 1인2역
# (0.9939, 12)	X[1] = 씨가, X[2] = 이렇게
# (0.8685, 12)	X[1] = 도경수, X[2] = 케미
# (0.8621, 12)	X[1] = 퍼스, X[2] = 의
# (0.8883, 12)	X[1] = 과, X[2] = 송지효
# (0.7326, 11)	X[1] = 연기, X[2] = 좋아
# (0.729, 11)	X[1] = 씨, X[2] = 이번
# (0.7969, 11)	X[-2] = 영화, X[-1] = 입니다, X[1] = 의, X[2] = 연기
# (0.9546, 11)	X[1] = 의, X[2] = 하드캐리
# (0.7581, 11)	X[1] = 님, X[2] = 짱
# (0.8631, 11)	X[1] = 님
# (0.957, 11)	X[-2] = 영화, X[-1] = 입니다, X[1] = 짱
# (0.9554, 11)	X[1] = 가, X[2] = 멋
# (0.9054, 11)	X[1] = 형님, X[2] = 때문
# (0.9884, 11)	X[1] = 완전, X[2] = 잘생김
# (0.9379, 11)	X[1] = 의, X[2] = 등장
# (0.7226, 11)	X[1] = 의, X[2] = 이미지
# (0.7265, 11)	X[1] = 만을, X[2] = 위한
# (0.8324, 11)	X[-2] = 없는, X[-1] = 영화, X[1] = 의, X[2] = 연기
# (0.8055, 11)	X[-2] = 도, X[-1] = 좋고, X[1] = 의, X[2] = 연
# (0.7256, 11)	X[1] = 님, X[2] = 영화
# (0.9501, 11)	X[1] = 님, X[2] = 진짜
# (0.922, 11)	X[-2] = 관람, X[-1] = 객, X[1] = 짱, X[2] = 진짜
# (0.7226, 11)	X[-2] = 관람, X[-1] = 객, X[1] = 의, X[2] = 존재감
# (0.8128, 11)	X[-2] = 관람, X[-1] = 객, X[1] = 연기, X[2] = 굿굿
# (0.7838, 11)	X[-2] = 관람, X[-1] = 객, X[1] = 이, X[2] = 잘생겨
# (0.7831, 11)	X[-2] = 관람, X[-1] = 객, X[1] = 은, X[2] = 진짜
# (0.7451, 11)	X[1] = 이기에, X[2] = 가능
# (0.8655, 11)	X[-2] = 관람, X[-1] = 객, X[1] = 은, X[2] = 최고
# (0.9993, 11)	X[-2] = 관람, X[-1] = 객, X[1] = 이, X[2] = 멋

# %% [markdown]
# 우리는 sparse vector representation 형태의 input data 를 만들었기 때문에 logistic regression 을 이용했습니다. 이와 다르게 X[-2], X[-1], X[1], X[2] 의 단어의 word vector 를 concatenation 한다면 neural network 의 input 이 될 수 있습니다. 이러한 방식이 아래의 Stanford 수업의 assignment 내용입니다.
#
# https://nlp.stanford.edu/~socherr/pa4_ner.pdf
#
# 또한 word vector 를 이용한다면 Convolutional Neural Network (CNN) 를 이용할 수도 있습니다. 특히나 CNN 은 n-gram features 를 이용하기 때문에 문맥 정보가 더 정확히 잡힐 수 있습니다. 이에 대해서는 다른 튜토리얼에서 다룹니다.
